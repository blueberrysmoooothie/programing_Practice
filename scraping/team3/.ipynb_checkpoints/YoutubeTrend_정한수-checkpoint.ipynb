# %% [markdown]
# 유투브 트렌드 분석 - 정한수
# - 자료 출처 : 플레이보드 https://playboard.co/

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re

# 월 코드
month_code = ['1609459200', '1612137600', '1614556800', '1617235200','1619827200', '1622505600', '1625097600','1627776000', '1630454400', '1633046400', '1635724800', '1638316800', 
              '1640995200', '1643673600', '1646092800', '1648771200', '1651363200', '1654041600']
# 개인 토픽
topics = ['howto', 'education', 'science', 'all']

# 조회수 url
viewed_url = ['https://playboard.co/youtube-ranking/most-viewed-','-channels-in-south-korea-monthly?period=']
# 인기순위 url
total_popular_url = 'https://playboard.co/youtube-ranking/most-popular-all-channels-in-south-korea-monthly?period='

# 특정월 url 생성 테스트
for topic in topics:
    print(topic.join(viewed_url)+month_code[0])
    
print(total_popular_url+month_code[0])
# Out:
# https://playboard.co/youtube-ranking/most-viewed-howto-channels-in-south-korea-monthly?period=1609459200
# https://playboard.co/youtube-ranking/most-viewed-education-channels-in-south-korea-monthly?period=1609459200
# https://playboard.co/youtube-ranking/most-viewed-science-channels-in-south-korea-monthly?period=1609459200
# https://playboard.co/youtube-ranking/most-viewed-all-channels-in-south-korea-monthly?period=1609459200
# https://playboard.co/youtube-ranking/most-popular-all-channels-in-south-korea-monthly?period=1609459200

# %% [markdown]
# ### 순위차트 클로링

# %%
# 조회수 순위 차트 크롤링
# url 내의 표에서 1위 부터 rank 순위 까지의 자료 찾기
def get_top_viewed(url,df_dict, rank = 1):
#     print(url)
    req = requests.get(url)
    soup = BeautifulSoup(req.text, 'html.parser')
    tabel = soup.select_one('table.sheet > tbody')
    
    if tabel == None:
        for i in range(rank):
            df_dict['순위'].append(0)
            df_dict['채널명'].append(np.nan)
            df_dict['태그'].append([])
            df_dict['조회수'].append(np.nan)
    else:
        trs = tabel.select('tr.chart__row')
        r = 0
        while True:
            tr = trs[r]
            name = np.nan
            tags = []
            month_rank = 0
            viewed = np.nan

            try:
                name = tr.find('h3').text
                tag_lis = tr.select('ul.name__tags > li.ttags__item')
                for tag_li in tag_lis:
                    tags.append(tag_li.text)
                month_rank = tr.select_one('div.current').text
                viewed = tr.select_one('td.score').text
                viewed = float(viewed.replace(',',''))
            except:
                print('ad')
                r += 1
                continue

            df_dict['순위'].append(month_rank)
            df_dict['채널명'].append(name)
            df_dict['태그'].append(tags)
            df_dict['조회수'].append(viewed)

            if int(month_rank) == rank:
                break
            r += 1
    return df_dict


def get_top_popular(url,df_dict, rank = 1):
#     print(url)
    req = requests.get(url)
    soup = BeautifulSoup(req.text, 'html.parser')
    tabel = soup.select_one('table.sheet > tbody')
    
    trs = tabel.select('tr.chart__row')
    if trs == None:
        trs= [None]
    r = 0
    
    while True:
        tr = trs[r]

        name = np.nan
        tags = []
        month_rank = 0
        viewed = np.nan
        likes = np.nan
        
        try:
            name = tr.find('h3').text
            tag_lis = tr.select('ul.name__tags > li.ttags__item')
            for tag_li in tag_lis:
                tags.append(tag_li.text)
            month_rank = tr.select_one('div.current').text

            score_tds = tr.select('td.score')
            viewed = score_tds[0].select_one('span').text
            viewed = float(viewed.replace(',',''))

            likes = score_tds[1].select_one('span').text
        except:
            print('ad')
            r += 1
            continue
                
        df_dict['순위'].append(month_rank)
        df_dict['채널명'].append(name)
        df_dict['태그'].append(tags)
        df_dict['조회수'].append(viewed)
        df_dict['likes'].append(likes)
        
        if int(month_rank) == rank:
            break
        r += 1
    return df_dict

# %%
# 전체 토픽의 월별 인기순위 1위
df_dict ={'순위':[], '채널명':[], '태그':[], '조회수':[], 'likes':[]} 
for mon in month_code:
#     print(month_code.index(mon), end = ': ')
    df_dict = get_top_popular(total_popular_url+mon,df_dict)

top_popular_df = pd.DataFrame(df_dict, index = pd.period_range('2021-01-01','2022-06-30',freq = 'm').to_list())
top_popular_df
# Out:
#         순위           채널명                                                 태그  \
# 2021-01  1     BANGTANTV                                    [ #BTS ,  #방탄 ]
# 2021-02  1     BANGTANTV                                    [ #BTS ,  #방탄 ]
# 2021-03  1     BLACKPINK                                    [ #YG ,  #와이지 ]
# 2021-04  1     BANGTANTV                                    [ #BTS ,  #방탄 ]
# 2021-05  1   HYBE LABELS                          [ #HYBE ,  #HYBE LABELS ]
# 2021-06  1     BANGTANTV                                    [ #BTS ,  #방탄 ]
# 2021-07  1     BANGTANTV                                    [ #BTS ,  #방탄 ]
# 2021-08  1         쇼츠갤러리                                                 []
# 2021-09  1     BLACKPINK                                    [ #YG ,  #와이지 ]
# 2021-10  1     BLACKPINK                                    [ #YG ,  #와이지 ]
# 2021-11  1     BANGTANTV                                    [ #BTS ,  #방탄 ]
# 2021-12  1     BANGTANTV                                    [ #BTS ,  #방탄 ]
# 2022-01  1         진성호방송                                     [ #인물 ,  #사회 ]
# 2022-02  1           YTN                                  [ #YTN ,  #LIVE ]
# 2022-03  1           YTN                                  [ #YTN ,  #LIVE ]
# 2022-04  1           YTN                                  [ #YTN ,  #LIVE ]
# 2022-05  1  Jᴇᴏɴɪᴄs♥︎방탄°  [ #Share by Tmate - Tiktok Downloader https://...
# 2022-06  1     BANGTANTV                                    [ #BTS ,  #방탄 ]
#
#                  조회수  likes
# 2021-01  102590678.0  1.5천만
# 2021-02   82683282.0  1.8천만
# 2021-03  253043478.0  2.1천만
# 2021-04  142585706.0  2.6천만
# 2021-05  442902465.0  3.5천만
# 2021-06  288032959.0  3.7천만
# 2021-07  486782715.0  7.4천만
# 2021-08  425145879.0  2.4백만
# 2021-09  448201000.0  3.6천만
# 2021-10  210293347.0    9백만
# 2021-11   85011004.0  1.4천만
# 2021-12  133597147.0  2.1천만
# 2022-01  134403876.0  9.5백만
# 2022-02  286339053.0  2.9백만
# 2022-03  428185583.0  3.9백만
# 2022-04  284824219.0  2.7백만
# 2022-05  118406472.0  1.8천만
# 2022-06  350639298.0  4.6천만

# %%
# 전체 토픽의 월별 인기순위 1위 ~ 15위
df_dict ={'순위':[], '채널명':[], '태그':[], '조회수':[], 'likes':[]} 
for mon in month_code:
#     print(month_code.index(mon), end = ': ')
    df_dict = get_top_popular(total_popular_url+mon,df_dict, rank = 15)

ind = pd.period_range('2021-01-01','2022-06-30',freq = 'm').to_list()*15
top_15_popular_df = pd.DataFrame(df_dict, index = sorted(ind))
top_15_popular_df
# Out:
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
# ad
#          순위        채널명                       태그          조회수  likes
# 2021-01   1  BANGTANTV          [ #BTS ,  #방탄 ]  102590678.0  1.5천만
# 2021-01   2  tvN drama       [ #tvN ,  #DRAMA ]  146548852.0  3.1백만
# 2021-01   3    Samsung  [ #samsung ,  #mobile ]  147055306.0  66.9만
# 2021-01   4    MBCNEWS        [ #mbc ,  #news ]  121795611.0  1.2백만
# 2021-01   5      진성호방송           [ #인물 ,  #사회 ]   67842701.0  5.3백만
# ...      ..        ...                      ...          ...    ...
# 2022-06  11   KBS News          [ #kbs ,  #뉴스 ]  103736906.0  77.7만
# 2022-06  12         M2         [ #Mnet ,  #엠넷 ]   60267324.0  4.9백만
# 2022-06  13     채널A 뉴스          [ #채널A ,  #시사 ]   92172782.0  1.5백만
# 2022-06  14     성창경 TV    [ #성창경TV ,  #성창경유튜브 ]   44686667.0    6백만
# 2022-06  15       홍꾸커플       [ #홍이누나 ,  #vlog ]   82616793.0    2백만
#
# [270 rows x 5 columns]

# %%
top_15_popular_df[:20]
# Out:
#          순위                                          채널명  \
# 2021-01   1                                    BANGTANTV
# 2021-01   2                                    tvN drama
# 2021-01   3                                      Samsung
# 2021-01   4                                      MBCNEWS
# 2021-01   5                                        진성호방송
# 2021-01   6                          Stop Motion Cooking
# 2021-01   7                                       SBS 뉴스
# 2021-01   8                                      배승희 변호사
# 2021-01   9                                  HYBE LABELS
# 2021-01  10                                          YTN
# 2021-01  11                                    BLACKPINK
# 2021-01  12  (G)I-DLE (여자)아이들 (Official YouTube Channel)
# 2021-01  13                           삼성전자 Samsung Korea
# 2021-01  14                               TREASURE (트레저)
# 2021-01  15                                 1theK (원더케이)
# 2021-02   1                                    BANGTANTV
# 2021-02   2                                       SMTOWN
# 2021-02   3                                      MBCNEWS
# 2021-02   4                                    tvN drama
# 2021-02   5                          Stop Motion Cooking
#
#                                         태그          조회수  likes
# 2021-01                    [ #BTS ,  #방탄 ]  102590678.0  1.5천만
# 2021-01                 [ #tvN ,  #DRAMA ]  146548852.0  3.1백만
# 2021-01            [ #samsung ,  #mobile ]  147055306.0  66.9만
# 2021-01                  [ #mbc ,  #news ]  121795611.0  1.2백만
# 2021-01                     [ #인물 ,  #사회 ]   67842701.0  5.3백만
# 2021-01              [ #cooking ,  #asmr ]  112447275.0     8천
# 2021-01               [ #SBSNEWS ,  #sbs ]   91520561.0    72만
# 2021-01  [ #bae seung hee lawyer ,  #배승희 ]   40858699.0  5.5백만
# 2021-01          [ #HYBE ,  #HYBE LABELS ]   38642488.0  5.5백만
# 2021-01                  [ #YTN ,  #LIVE ]   83309188.0  66.8만
# 2021-01                    [ #YG ,  #와이지 ]   42866128.0  4.6백만
# 2021-01                [ #kpop ,  #gidle ]   64296689.0  2.4백만
# 2021-01         [ #삼성전자 ,  #SamsungKorea ]   78200053.0   5.7만
# 2021-01              [ #TREASURE ,  #트레저 ]   35943121.0  3.9백만
# 2021-01                [ #1theK ,  #원더케이 ]   42242549.0  3.1백만
# 2021-02                    [ #BTS ,  #방탄 ]   82683282.0  1.8천만
# 2021-02         [ #SuperJunior ,  #슈퍼주니어 ]   80962335.0    5백만
# 2021-02                  [ #mbc ,  #news ]  111596808.0    1백만
# 2021-02                 [ #tvN ,  #DRAMA ]  101751604.0  1.8백만
# 2021-02              [ #cooking ,  #asmr ]  110186216.0   2.6만

# %%
# 전체 토픽, 특정 토픽의 조회수 순위 1위
viewed_dfs = {}
for topic in topics:
    print('-'*30, '\n', topic, ':')
    df_dict ={'순위':[], '채널명':[], '태그':[], '조회수':[]} 
    for mon in month_code:
#         print(month_code.index(mon), end = ': ')
        df_dict = get_top_viewed(topic.join(viewed_url)+mon, df_dict)
#         print('채널명 : {0:10}, 태그 : {1}, 조회수 : {2:10}'.format(values[0], values[1], values[2]))

    viewed_df = pd.DataFrame(df_dict, index = pd.period_range('2021-01-01','2022-06-30',freq = 'm'))
    viewed_dfs[topic] = viewed_df
viewed_dfs[topics[0]]
# Out:
# ------------------------------
#  howto :
# ------------------------------
#  education :
# ------------------------------
#  science :
# ------------------------------
#  all :
#         순위                채널명                               태그          조회수
# 2021-01  0                NaN                               []          NaN
# 2021-02  0                NaN                               []          NaN
# 2021-03  0                NaN                               []          NaN
# 2021-04  0                NaN                               []          NaN
# 2021-05  1  Yummy Waffle 야미와플            [ #Yummy ,  #Waffle ]   38935630.0
# 2021-06  1        YogaHoliday  [ #yogatoday ,  #yoga massage ]  110946503.0
# 2021-07  1        YogaHoliday  [ #yogatoday ,  #yoga massage ]   65970402.0
# 2021-08  1    ROOKIE MING 루키밍        [ #slime ,  #rookieming ]   69415860.0
# 2021-09  1    ROOKIE MING 루키밍        [ #slime ,  #rookieming ]   70017273.0
# 2021-10  1      쇼츠갤러리 tiktok                  [ #웃긴영상 ,  #동물 ]  114418328.0
# 2021-11  1    ROOKIE MING 루키밍        [ #slime ,  #rookieming ]   56094673.0
# 2021-12  1    ROOKIE MING 루키밍        [ #slime ,  #rookieming ]   74526721.0
# 2022-01  1    ROOKIE MING 루키밍        [ #slime ,  #rookieming ]  185794419.0
# 2022-02  1        jenny slime         [ #slimevideo ,  #asmr ]  107766406.0
# 2022-03  1              힐링 쇼츠               [ #shorts ,  #쇼츠 ]  112988071.0
# 2022-04  1        jenny slime         [ #slimevideo ,  #asmr ]  103141590.0
# 2022-05  1         5 분 Tricks               [ #DIY ,  #hacks ]   78922999.0
# 2022-06  1         5 분 Tricks               [ #DIY ,  #hacks ]  144810516.0

# %%
viewed_dfs[topics[1]]
# Out:
#         순위             채널명                       태그          조회수
# 2021-01  1   스위트티비 SweetTV          [ #장난감 ,  #놀이 ]  136648367.0
# 2021-02  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   72135733.0
# 2021-03  1   스위트티비 SweetTV          [ #장난감 ,  #놀이 ]   97339243.0
# 2021-04  1   스위트티비 SweetTV          [ #장난감 ,  #놀이 ]  108905985.0
# 2021-05  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   58035190.0
# 2021-06  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   49414221.0
# 2021-07  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   66542989.0
# 2021-08  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   98427573.0
# 2021-09  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   82265447.0
# 2021-10  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   94481365.0
# 2021-11  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   78184075.0
# 2021-12  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   95247462.0
# 2022-01  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   92787223.0
# 2022-02  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   87406270.0
# 2022-03  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   87467854.0
# 2022-04  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   81021825.0
# 2022-05  1  CoCosToy 꼬꼬스토이  [ #어린이만화 ,  #dinosaur ]   58343917.0
# 2022-06  1  핑크퐁 (인기 동요・동화)    [ #핑크퐁 ,  #pinkfong ]   67285705.0

# %%
viewed_dfs[topics[2]]
# Out:
#         순위                         채널명                               태그  \
# 2021-01  1                     Samsung          [ #samsung ,  #mobile ]
# 2021-02  1                     Samsung          [ #samsung ,  #mobile ]
# 2021-03  1                     Samsung          [ #samsung ,  #mobile ]
# 2021-04  1                     Samsung          [ #samsung ,  #mobile ]
# 2021-05  1                     Samsung          [ #samsung ,  #mobile ]
# 2021-06  1                     Samsung          [ #samsung ,  #mobile ]
# 2021-07  1                     ITSub잇섭                 [ #it ,  #전자제품 ]
# 2021-08  1  새로운거신기한거재밌는거 NewAmazingFun               [ #신기한거 ,  #새로운거 ]
# 2021-09  1  새로운거신기한거재밌는거 NewAmazingFun               [ #신기한거 ,  #새로운거 ]
# 2021-10  1                     Samsung          [ #samsung ,  #mobile ]
# 2021-11  1                     Samsung          [ #samsung ,  #mobile ]
# 2021-12  1                  Seegene 씨젠        [ #Seegene ,  #Covid-19 ]
# 2022-01  1                     Samsung          [ #samsung ,  #mobile ]
# 2022-02  1                    Ok Drama  [ #OkDrama ,  #Jianyiofficial ]
# 2022-03  1                    Ok Drama  [ #OkDrama ,  #Jianyiofficial ]
# 2022-04  1                    Ok Drama  [ #OkDrama ,  #Jianyiofficial ]
# 2022-05  1               ox_zung / 원정맨           [ #ox_zung ,  #funny ]
# 2022-06  1               ox_zung / 원정맨           [ #ox_zung ,  #funny ]
#
#                  조회수
# 2021-01  139915851.0
# 2021-02   21373247.0
# 2021-03   67158587.0
# 2021-04   72171001.0
# 2021-05   42711664.0
# 2021-06   30394049.0
# 2021-07   18976829.0
# 2021-08  147895228.0
# 2021-09   75538531.0
# 2021-10  113259374.0
# 2021-11  139505687.0
# 2021-12   56359040.0
# 2022-01  106727813.0
# 2022-02  308027915.0
# 2022-03  232312261.0
# 2022-04  215611308.0
# 2022-05  258505883.0
# 2022-06  173865601.0

# %%
viewed_dfs[topics[3]]
# Out:
#         순위          채널명                         태그          조회수
# 2021-01  1    BLACKPINK            [ #YG ,  #와이지 ]  602459523.0
# 2021-02  1    BLACKPINK            [ #YG ,  #와이지 ]  486769203.0
# 2021-03  1    BLACKPINK            [ #YG ,  #와이지 ]  730292850.0
# 2021-04  1  HYBE LABELS  [ #HYBE ,  #HYBE LABELS ]  631260181.0
# 2021-05  1  HYBE LABELS  [ #HYBE ,  #HYBE LABELS ]  956989989.0
# 2021-06  1  HYBE LABELS  [ #HYBE ,  #HYBE LABELS ]  701819165.0
# 2021-07  1    BANGTANTV            [ #BTS ,  #방탄 ]  891562499.0
# 2021-08  1    BANGTANTV            [ #BTS ,  #방탄 ]  598802040.0
# 2021-09  1    BLACKPINK            [ #YG ,  #와이지 ]  820595696.0
# 2021-10  1    BLACKPINK            [ #YG ,  #와이지 ]  696333772.0
# 2021-11  1    BLACKPINK            [ #YG ,  #와이지 ]  596645061.0
# 2021-12  1    BANGTANTV            [ #BTS ,  #방탄 ]  509184473.0
# 2022-01  1    BLACKPINK            [ #YG ,  #와이지 ]  459914510.0
# 2022-02  1    BLACKPINK            [ #YG ,  #와이지 ]  397843290.0
# 2022-03  1          YTN          [ #YTN ,  #LIVE ]  502063619.0
# 2022-04  1  HYBE LABELS  [ #HYBE ,  #HYBE LABELS ]  332826486.0
# 2022-05  1  HYBE LABELS  [ #HYBE ,  #HYBE LABELS ]  477852535.0
# 2022-06  1    BANGTANTV            [ #BTS ,  #방탄 ]  683041687.0

# %% [markdown]
# 토픽 별 조회수 1위 수치 변화 비교

# %%
topics
# Out:
# ['howto', 'education', 'science', 'all']

# %%
view_top_path = './topic_view_top1/'
for topic in topics:
    viewed_dfs[topic].to_csv(view_top_path + f'{topic}_view_top.csv', encoding = 'utf-8', index = True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import platform
if platform.system() == 'Windows':
    plt.rc('font', family='Malgun Gothic')
else:
    plt.rc('font', family='AppleGothic')
    
plt.style.use('ggplot')

# %%
colors = sns.color_palette('hls', 4)
    
plt.figure(figsize=(16,6))
plt.xticks(range(len(viewed_dfs[topics[-1]].index)), viewed_dfs[topics[-1]].index, rotation=80)
    
for topic in topics[:-1]:
    plt.plot(range(18),viewed_dfs[topic]['조회수'],
             'o--', color = colors[topics.index(topic)+1])

# plt.bar(range(18), viewed_dfs[topics[-1]]['조회수'], alpha = 0.5, color = colors[0])


plt.legend(topics,loc = 2)

# %% [markdown]
# science 분야 영상 채널이 2022년 2월 에 급증

# %% [markdown]
# 통합 1위의 채널과의 조회수 비교

# %%
colors = sns.color_palette('hls', 4)
    
plt.figure(figsize=(16,6))
plt.xticks(range(len(viewed_dfs[topics[-1]].index)), viewed_dfs[topics[-1]].index, rotation=80)
    
for topic in topics[:-1]:
    plt.plot(range(18),viewed_dfs[topic]['조회수'],
             'o--', color = colors[topics.index(topic)+1])

plt.bar(range(18), viewed_dfs[topics[-1]]['조회수'], alpha = 0.5, color = colors[0])


plt.legend(topics,loc = 2)

# %% [markdown]
# 22년 2월에는 과학분야가 1위의 조회수와 유사해 보이지만 그외에는 세 분야 모두 비교적으로 적은 조회수를 보인다.

# %% [markdown]
# 전체 분석
#
# - 조원별로 나눈 토픽별 자료들을 모아 분석

# %% [markdown]
# #### 월간 15위 채널의 등록 태그 분석

# %%
top_15_popular_df
# Out:
#          순위        채널명                       태그          조회수  likes
# 2021-01   1  BANGTANTV          [ #BTS ,  #방탄 ]  102590678.0  1.5천만
# 2021-01   2  tvN drama       [ #tvN ,  #DRAMA ]  146548852.0  3.1백만
# 2021-01   3    Samsung  [ #samsung ,  #mobile ]  147055306.0  66.9만
# 2021-01   4    MBCNEWS        [ #mbc ,  #news ]  121795611.0  1.2백만
# 2021-01   5      진성호방송           [ #인물 ,  #사회 ]   67842701.0  5.3백만
# ...      ..        ...                      ...          ...    ...
# 2022-06  11   KBS News          [ #kbs ,  #뉴스 ]  103736906.0  77.7만
# 2022-06  12         M2         [ #Mnet ,  #엠넷 ]   60267324.0  4.9백만
# 2022-06  13     채널A 뉴스          [ #채널A ,  #시사 ]   92172782.0  1.5백만
# 2022-06  14     성창경 TV    [ #성창경TV ,  #성창경유튜브 ]   44686667.0    6백만
# 2022-06  15       홍꾸커플       [ #홍이누나 ,  #vlog ]   82616793.0    2백만
#
# [270 rows x 5 columns]

# %% [markdown]
# 월간 전체토픽의 인기순위

# %%
month_tags = top_15_popular_df.reset_index().groupby('index')['태그'].sum()
month_tags
# Out:
# index
# 2021-01    [ #BTS ,  #방탄 ,  #tvN ,  #DRAMA ,  #samsung , ...
# 2021-02    [ #BTS ,  #방탄 ,  #SuperJunior ,  #슈퍼주니어 ,  #mb...
# 2021-03    [ #YG ,  #와이지 ,  #BTS ,  #방탄 ,  #mbc ,  #news ...
# 2021-04    [ #BTS ,  #방탄 ,  #HYBE ,  #HYBE LABELS ,  #mbc...
# 2021-05    [ #HYBE ,  #HYBE LABELS ,  #BTS ,  #방탄 ,  #Sup...
# 2021-06    [ #BTS ,  #방탄 ,  #HYBE ,  #HYBE LABELS ,  #mbc...
# 2021-07    [ #BTS ,  #방탄 ,  #HYBE ,  #HYBE LABELS ,  #Tik...
# 2021-08    [ #BTS ,  #방탄 ,  #HYBE ,  #HYBE LABELS ,  #mbc...
# 2021-09    [ #YG ,  #와이지 ,  #BTS ,  #방탄 ,  #JYP ,  #jypen...
# 2021-10    [ #YG ,  #와이지 ,  #BTS ,  #방탄 ,  #SuperJunior ,...
# 2021-11    [ #BTS ,  #방탄 ,  #장난감 ,  #자동차 ,  #JYP ,  #jype...
# 2021-12    [ #BTS ,  #방탄 ,  #mbc ,  #news ,  #SuperJunior...
# 2022-01    [ #인물 ,  #사회 ,  #YTN ,  #LIVE ,  #mbc ,  #news...
# 2022-02    [ #YTN ,  #LIVE ,  #인물 ,  #사회 ,  #OkDrama ,  #...
# 2022-03    [ #YTN ,  #LIVE ,  #인물 ,  #사회 ,  #mbc ,  #news...
# 2022-04    [ #YTN ,  #LIVE ,  #mbc ,  #news ,  #Share by ...
# 2022-05    [ #Share by Tmate - Tiktok Downloader https://...
# 2022-06    [ #BTS ,  #방탄 ,  #HYBE ,  #HYBE LABELS ,  #mbc...
# Freq: M, Name: 태그, dtype: object

# %%
from wordcloud import WordCloud
if platform.system() == 'Windows':
    path = r'c:\Windows\Fonts\malgun.ttf'
elif platform.system() == 'Darwin':
    path = r'/System/Library/Fonts/AppleGothic'
else:
    path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'

times = ['2021 상반기', '2021 하반기', '2022 상반기']
q_tags = [month_tags[:6].sum(), month_tags[6:12].sum(), month_tags[12:].sum()]
for i in range(3):
    print(times[i])
    tag_counts = dict(pd.Series(q_tags[0]).str.lstrip(' #').value_counts())

    wc = WordCloud(font_path=path, background_color="white", max_font_size=60)
    cloud = wc.generate_from_frequencies(tag_counts)
    plt.figure(figsize=(16, 8))
    plt.subplot(1,2,1)
    
    plt.axis('off')    
    plt.imshow(cloud)
    plt.subplot(1,2,2)
    plt.barh(list(tag_counts.keys())[:15], list(tag_counts.values())[:15])
    plt.show()
# Out:
# 2021 상반기
# 2021 하반기
# 2022 상반기

# %%
# 조원들이 크롤링한 자료 불러오기
view_top_path = './topic_view_top1/'
import os
topics = []
viewed_dfs = {}
for f_name in os.listdir(view_top_path):
    topic =  f_name.split('_view')[0].split('.csv')[0]
#     re.search('.+(?=_view)', re.search('.+(?=.csv)', f_name).group())
    topics.append(topic)
    
    topic_df = pd.read_csv(view_top_path+f_name, encoding = 'utf-8')
    print(topic, list(topic_df.columns))
    if topic_df['조회수'].dtype == 'object':
        topic_df['조회수'] = topic_df['조회수'].str.replace(',', '').astype('float')
    topic_df.rename(columns = {'채널이름': '채널명'}, inplace=True)
    viewed_dfs[topic] = topic_df
# Out:
# all ['Unnamed: 0', '순위', '채널명', '태그', '조회수']
# animals ['Unnamed: 0', '채널명', '조회수']
# baking ['Unnamed: 0', '채널명', '조회수']
# body-building ['Unnamed: 0', '채널명', '조회수']
# camping ['Unnamed: 0', '채널명', '조회수']
# cat ['Unnamed: 0', '채널명', '조회수']
# comedy ['Unnamed: 0', '채널이름', '조회수']
# cooking ['Unnamed: 0', '채널명', '조회수']
# cover-dance ['Unnamed: 0', '채널명', '조회수']
# cover-song ['Unnamed: 0', '채널명', '조회수']
# dog ['Unnamed: 0', '채널명', '조회수']
# education ['Unnamed: 0', '순위', '채널명', '태그', '조회수']
# entertainment ['Unnamed: 0', '채널이름', '조회수']
# fashion ['Unnamed: 0', '채널명', '조회수']
# film ['Unnamed: 0', '채널이름', '조회수']
# gaming ['Unnamed: 0', '채널명', '조회수']
# home_workout ['Unnamed: 0', '채널명', '조회수']
# howto ['Unnamed: 0', '순위', '채널명', '태그', '조회수']
# lookbook ['Unnamed: 0', '채널명', '조회수']
# makeup ['Unnamed: 0', '채널명', '조회수']
# mukbang ['Unnamed: 0', '채널명', '조회수']
# music ['Unnamed: 0', '채널명', '조회수']
# news ['Unnamed: 0', '채널명', '조회수']
# science ['Unnamed: 0', '순위', '채널명', '태그', '조회수']
# sneakers ['Unnamed: 0', '채널명', '조회수']
# sports ['Unnamed: 0', '채널이름', '조회수']
# stocks ['Unnamed: 0', '채널명', '조회수']
# travel ['Unnamed: 0', '채널이름', '조회수']
# trucker ['Unnamed: 0', '채널명', '조회수']
# v-tuber ['Unnamed: 0', '채널명', '조회수']
# vehicles ['Unnamed: 0', '채널이름', '조회수']
# vlog ['Unnamed: 0', '채널이름', '조회수']

# %%
colors = sns.color_palette('hls', len(topics))
    
ind = pd.period_range('2021-01-01','2022-06-30',freq = 'm')

plt.figure(figsize=(16,6))
plt.xticks(range(len(ind)), ind, rotation=80)
    
plt.bar(range(18), viewed_dfs[topics[0]]['조회수'], alpha = 0.5, color = colors[0])
plt.legend([topics[0]],loc = 2, fontsize= 20)
for topic in topics[1:]:
    views = viewed_dfs[topic]['조회수']
    plt.plot(range(18),views,
             'o--', color = colors[topics.index(topic)])


#     plt.text(13.5,views.iloc[7] , topic, fontsize=20, color='green')

plt.text(6.5,viewed_dfs['vlog']['조회수'].iloc[7] , 'vlog', fontsize=20, color='c')
plt.text(13.5,viewed_dfs['news']['조회수'].iloc[14] +100, 'news', fontsize=20, color='c')
plt.text(1.5,viewed_dfs['music']['조회수'].iloc[2] +100, 'music', fontsize=20, color='c')
plt.show()

# %% [markdown]
# 음악 분야가 매월 가장 높은 조회수를 보이며
# 22년 3월 news분야가 가장 조회수가 높았다. 3월 9일 시행된 대통령 선거의 영향
# 21년 8월 vlog분야의 조회수 급상승이 있었는데 이는 휴가시즌의 영향으로 보인다.

# %%
selected_topic = ['gaming', 'science', 'makeup', 'vehicles','mukbang']

plt.figure(figsize=(16,6))
plt.xticks(range(len(ind)), ind, rotation=80)
    
plt.bar(range(18), viewed_dfs[topics[0]]['조회수'], alpha = 0.5, color = colors[0])
for topic in selected_topic:
    views = viewed_dfs[topic]['조회수']
    plt.plot(range(18),views,
             'o--', color = colors[topics.index(topic)])
    
plt.legend( selected_topic +[topics[0]],loc = 2, fontsize= 16)

plt.show()

# %% [markdown]
# 월별 토픽들의 조회수 순위 구하기

# %%
merged_df = pd.DataFrame(index = range(18))
for topic in topics[1:]:
    topic_df = viewed_dfs[topic][['채널명', '조회수']].copy()
    topic_df.columns = [topic+'채널명', topic+'조회수']
    merged_df = pd.concat([merged_df, topic_df], axis = 1)   
# merged_df.index = ind
merged_df
# Out:
#                        animals채널명  animals조회수            baking채널명  \
# 0   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  85081740.0                  NaN
# 1   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  66270793.0      Boone Bake분 베이크
# 2   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  73697164.0      Boone Bake분 베이크
# 3   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  75296671.0    Cooking tree 쿠킹트리
# 4   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  83486054.0    Cooking tree 쿠킹트리
# 5   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  78049300.0    Cooking tree 쿠킹트리
# 6   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  59003796.0            서담 seodam
# 7   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  53589577.0  조꽁드Joconde's baking
# 8   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  42890636.0  조꽁드Joconde's baking
# 9   SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  40825430.0    Cooking tree 쿠킹트리
# 10  SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  39683992.0  조꽁드Joconde's baking
# 11                  [THE SOY]루퐁이네  49541674.0     식탁일기 table diary
# 12  SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  51508731.0    Cooking tree 쿠킹트리
# 13  SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  46078152.0    Cooking tree 쿠킹트리
# 14  SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  52175700.0     식탁일기 table diary
# 15  SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  44812759.0    Cooking tree 쿠킹트리
# 16       KBS동물티비 : 애니멀포유 animal4u  39368949.0      Boone Bake분 베이크
# 17  SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!  47723877.0     식탁일기 table diary
#
#      baking조회수                body-building채널명  body-building조회수  \
# 0          NaN                             NaN               NaN
# 1   15041208.0                          피지컬갤러리        15900692.0
# 2    8947082.0                          피지컬갤러리        14528418.0
# 3    7265231.0                          피지컬갤러리         8399004.0
# 4    7429295.0                             지피티        13803434.0
# 5    7431352.0                          피지컬갤러리        19538685.0
# 6   14076915.0  헬창TV Korea Fitness HellchangTV        11023292.0
# 7    7929312.0                             지피티        11688829.0
# 8    9558681.0                          피지컬갤러리         8192377.0
# 9    5788011.0                          피지컬갤러리        12256301.0
# 10   7808909.0                      MBC every1        12461154.0
# 11  17021504.0                          피지컬갤러리        12532756.0
# 12   7345101.0                             박승현        22901908.0
# 13   6456686.0                             박승현        28186301.0
# 14  13557217.0                             박승현        49914726.0
# 15   6073938.0                             박승현        31083248.0
# 16   7646159.0                             박승현        49009898.0
# 17   9831359.0                             박승현        63965260.0
#
#       camping채널명  camping조회수                   cat채널명      cat조회수  ...  \
# 0            NaN         NaN                      NaN         NaN  ...
# 1   Rirang OnAir   2810020.0                   크림히어로즈  16137618.0  ...
# 2           캠핑제국   5713269.0       밀키복이탄이MilkyBokiTan  19462122.0  ...
# 3           캠핑제국   7243472.0            금수강산Kpetworld  32814388.0  ...
# 4           은하캠핑  11481395.0       밀키복이탄이MilkyBokiTan  20000775.0  ...
# 5           캠핑제국  10487107.0       밀키복이탄이MilkyBokiTan  17718141.0  ...
# 6           캠핑제국   7584436.0                      크집사  17149721.0  ...
# 7           캠핑제국  14266663.0                      크집사  19576139.0  ...
# 8           승우아빠  13886970.0                      시멘트  20867486.0  ...
# 9           캠핑제국   7743002.0                      시멘트  25273408.0  ...
# 10  Rirang OnAir   9519082.0                      시멘트  17710152.0  ...
# 11    MBC every1  11375630.0                      시멘트  25303806.0  ...
# 12    MBC every1  18562997.0                      시멘트  18721857.0  ...
# 13          캠핑제국   9236276.0  스튜디오 와플 - STUDIO WAFFLE  19838585.0  ...
# 14  Rirang OnAir   9304070.0  스튜디오 와플 - STUDIO WAFFLE  31041796.0  ...
# 15     부산여자하쿠짱TV   6566959.0                   크림히어로즈  13473200.0  ...
# 16          캠핑제국   4552560.0                   크림히어로즈  12573322.0  ...
# 17  Rirang OnAir   7780981.0                   크림히어로즈  14245461.0  ...
#
#              travel채널명    travel조회수              trucker채널명  trucker조회수  \
# 0    푸드킹덤 Food Kingdom   59119166.0                     NaN         NaN
# 1    푸드킹덤 Food Kingdom   29946210.0          트럭커 디젤집시의 Vlog   1523587.0
# 2    푸드킹덤 Food Kingdom   36839831.0                    군복남자   1495164.0
# 3        야미보이 Yummyboy   31207792.0                    군복남자   1689721.0
# 4    푸드킹덤 Food Kingdom   37867434.0                     권마키   2215444.0
# 5        피기보이 PiggyBoy   34121156.0                   빠꾸왕간디   1117346.0
# 6        야미보이 Yummyboy   39318482.0                     권마키   4250374.0
# 7    푸드킹덤 Food Kingdom   56414137.0                   빠꾸왕간디   5235450.0
# 8   Imagine your Korea  156046213.0                     권마키   1456030.0
# 9          I'm perfect   49003323.0                     권마키   2777722.0
# 10      Soon Films 순필름   46699879.0                     권마키   4398510.0
# 11       찐푸드 JJin Food   46854545.0                     권마키   2250966.0
# 12  푸드클럽 The Food Club   41968897.0                     권마키   3171907.0
# 13  Imagine your Korea   36069153.0                     권마키   2509361.0
# 14   푸드킹덤 Food Kingdom   22839384.0                     권마키   3647274.0
# 15       야미보이 Yummyboy   34440549.0                     권마키   2431285.0
# 16  Imagine your Korea   49554221.0                     권마키   2482193.0
# 17  Imagine your Korea   93253987.0  륭TV Amazing Technology   5879498.0
#
#         v-tuber채널명  v-tuber조회수          vehicles채널명  vehicles조회수  \
# 0      ShiningStar   2549400.0               한문철 TV   18597173.0
# 1        아구이뽀 A924   3876929.0               한문철 TV   12034246.0
# 2        아구이뽀 A924   3477273.0               한문철 TV   27339413.0
# 3               요극   3411560.0               한문철 TV   28940032.0
# 4    홀로라이브KR 번역&자막    981984.0  Hankook Tire Global  125092472.0
# 5     오리고기 ORIGOGI  11869237.0               한문철 TV   31267383.0
# 6     오리고기 ORIGOGI  14107080.0               한문철 TV   32648445.0
# 7     오리고기 ORIGOGI  14539309.0               한문철 TV  108318784.0
# 8         번역하는 댕댕이   2087741.0               한문철 TV  142896200.0
# 9         번역하는 댕댕이   3194764.0               한문철 TV   87552956.0
# 10  징버거 JINGBURGER   2076786.0               한문철 TV   55166338.0
# 11         아이네 INE   2864244.0               한문철 TV   64552916.0
# 12         아이네 INE   7077305.0               한문철 TV   70852817.0
# 13         아이네 INE   9187810.0               한문철 TV   64896105.0
# 14   케이맨 King Kman  18940037.0               한문철 TV   57489554.0
# 15         아이네 INE   7813557.0               한문철 TV   36094412.0
# 16         아이네 INE   8878685.0               한문철 TV   44729742.0
# 17      비챤 VIichan  10814488.0            road Chin   61312934.0
#
#                   vlog채널명      vlog조회수
# 0                   진성호방송   67842701.0
# 1                   진성호방송   50365223.0
# 2                   진성호방송   93920566.0
# 3                   진성호방송  107751239.0
# 4               NCT DREAM   62261881.0
# 5           구독자90,000명만들기  156212737.0
# 6      짧은 영상 shorts video  172121317.0
# 7                   쇼츠갤러리  425145879.0
# 8                   진성호방송   95513544.0
# 9                   진성호방송  114011867.0
# 10                  진성호방송  112892660.0
# 11                  진성호방송  107778103.0
# 12                  진성호방송  134403876.0
# 13                  진성호방송  147660362.0
# 14                  진성호방송  205599478.0
# 15           Jᴇᴏɴɪᴄs♥︎방탄°   98655183.0
# 16           Jᴇᴏɴɪᴄs♥︎방탄°  118406472.0
# 17  [1분예능] 재미있고 감동적인 1분영상  205303358.0
#
# [18 rows x 62 columns]

# %%
merge_view_df = merged_df.filter(like='조회수')
month_top_topic = merge_view_df.apply(lambda x :pd.Series([topic.strip('조회수') for topic in  list(x.sort_values(ascending = False).index)]) , axis = 1)
month_top_topic
# Out:
#        0              1              2              3              4   \
# 0   music        mukbang  entertainment        science      education
# 1   music        mukbang           news  entertainment      education
# 2   music        mukbang           news  entertainment      education
# 3   music           news        mukbang  entertainment      education
# 4   music           news         comedy        mukbang  entertainment
# 5   music           news        mukbang           vlog  entertainment
# 6   music  entertainment           news        mukbang           vlog
# 7   music           vlog           news        science        mukbang
# 8   music        mukbang           news         travel       vehicles
# 9   music        mukbang           news  entertainment           film
# 10  music  entertainment           news        mukbang        science
# 11  music           news  entertainment         gaming        mukbang
# 12  music           news          howto        mukbang         gaming
# 13  music           news        science        mukbang         gaming
# 14   news          music        science           vlog         gaming
# 15  music           news        science         comedy        mukbang
# 16  music           news        science        mukbang         gaming
# 17  music           news           vlog        mukbang        science
#
#                5              6              7              8              9   \
# 0            news        animals         gaming           vlog         travel
# 1          gaming        animals           vlog     cover-song           film
# 2            vlog        animals        science         gaming    cover-dance
# 3            vlog         gaming        animals        science         sports
# 4        vehicles         gaming        animals           vlog      education
# 5           howto         comedy         gaming        animals      education
# 6          stocks         gaming         comedy      education          howto
# 7        vehicles      education  entertainment         stocks          howto
# 8   entertainment           vlog      education        science          howto
# 9           howto           vlog        science      education       vehicles
# 10           vlog         gaming      education         comedy          howto
# 11           vlog      education          howto        cooking         comedy
# 12           vlog  entertainment        science      education       vehicles
# 13           vlog          howto         stocks      education  entertainment
# 14        mukbang          howto  entertainment         stocks      education
# 15         gaming  entertainment          howto           vlog      education
# 16           vlog  entertainment         comedy           film          howto
# 17         gaming          howto         travel  entertainment           film
#
#     ...             21             22             23            24  \
# 0   ...        camping            cat        cooking   cover-dance
# 1   ...  body-building         baking       vehicles       fashion
# 2   ...  body-building   home_workout         baking       fashion
# 3   ...   home_workout  body-building        fashion        baking
# 4   ...         makeup  body-building   home_workout       camping
# 5   ...   home_workout            cat         makeup       v-tuber
# 6   ...            cat        v-tuber         baking  home_workout
# 7   ...            dog        v-tuber        camping  home_workout
# 8   ...     cover-song            cat        camping      lookbook
# 9   ...        fashion    cover-dance  body-building  home_workout
# 10  ...    cover-dance            cat  body-building  home_workout
# 11  ...     cover-song       lookbook        fashion        baking
# 12  ...  body-building   home_workout     cover-song           cat
# 13  ...   home_workout            cat     cover-song   cover-dance
# 14  ...         travel    cover-dance     cover-song       v-tuber
# 15  ...        fashion            dog     cover-song           cat
# 16  ...         sports            dog        fashion           cat
# 17  ...    cover-dance     cover-song        fashion      lookbook
#
#                25            26             27            28        29  \
# 0      cover-song           dog        fashion  home_workout     howto
# 1         v-tuber       camping       lookbook       trucker  sneakers
# 2         camping      lookbook        v-tuber      sneakers   trucker
# 3         camping      lookbook        v-tuber       trucker  sneakers
# 4         fashion        baking       lookbook       trucker   v-tuber
# 5         fashion       camping         baking      lookbook   trucker
# 6   body-building       fashion        camping      lookbook   trucker
# 7   body-building       fashion       lookbook        baking   trucker
# 8          baking  home_workout  body-building       v-tuber   trucker
# 9        lookbook       camping         baking       v-tuber  sneakers
# 10       lookbook       camping         baking       trucker   v-tuber
# 11  body-building  home_workout        camping       v-tuber   trucker
# 12        camping   cover-dance         baking       v-tuber   trucker
# 13       lookbook       camping        v-tuber        baking   trucker
# 14        fashion        baking       lookbook       camping   trucker
# 15       lookbook       v-tuber        camping        baking   trucker
# 16       lookbook       v-tuber         baking       camping   trucker
# 17            cat       v-tuber         baking       camping   trucker
#
#           30
# 0    trucker
# 1      howto
# 2      howto
# 3      howto
# 4   sneakers
# 5   sneakers
# 6   sneakers
# 7   sneakers
# 8   sneakers
# 9    trucker
# 10  sneakers
# 11  sneakers
# 12  sneakers
# 13  sneakers
# 14  sneakers
# 15  sneakers
# 16  sneakers
# 17  sneakers
#
# [18 rows x 31 columns]

# %%
topic_rank_df = pd.DataFrame(index = ind)
for topic in topics[1:]:
    ranks = month_top_topic.apply(lambda x: list(x).index(topic), axis = 1)
    topic_rank_df[topic] = list(ranks)
topic_rank_df
# Out:
#          animals  baking  body-building  camping  cat  comedy  cooking  \
# 2021-01        6      19             20       21   22      13       23
# 2021-02        6      22             21       26   19      17       16
# 2021-03        6      23             21       25   19      20       15
# 2021-04        7      24             22       25   10      19       17
# 2021-05        7      26             22       24   20       2       18
# 2021-06        8      27             20       26   22       6       10
# 2021-07       11      23             25       27   21       7       10
# 2021-08       12      28             25       23   18      13       16
# 2021-09       14      25             27       23   22      13       12
# 2021-10       13      27             23       26   18      10       14
# 2021-11       15      27             23       26   22       8       16
# 2021-12       12      24             25       27   19       9        8
# 2022-01       12      27             21       25   24      15       13
# 2022-02       13      28             20       26   22      14       12
# 2022-03       14      26             15       28   20      11       13
# 2022-04       14      28             19       27   24       3       13
# 2022-05       20      27             16       28   24       7       18
# 2022-06       17      27             14       28   25      15       18
#
#          cover-dance  cover-song  dog  ...  news  science  sneakers  sports  \
# 2021-01           24          25   26  ...     5        3        18      12
# 2021-02           14           8   12  ...     2       15        29      10
# 2021-03            9          13   16  ...     2        7        28      10
# 2021-04           16          13   11  ...     1        8        29       9
# 2021-05           17          14   19  ...     1       10        30      13
# 2021-06           14          17   19  ...     1       15        30      16
# 2021-07           19          17   14  ...     2       20        30      16
# 2021-08           19          17   21  ...     2        3        30      14
# 2021-09           20          21   17  ...     2        8        30      15
# 2021-10           22          20   19  ...     2        7        29      16
# 2021-11           21          20   19  ...     2        4        30      17
# 2021-12           20          21   13  ...     1       11        30      18
# 2022-01           26          23   20  ...     1        7        30      19
# 2022-02           24          23   18  ...     1        2        30      17
# 2022-03           22          23   19  ...     0        2        30      18
# 2022-04           16          23   22  ...     1        2        30      18
# 2022-05           14          11   22  ...     1        2        30      21
# 2022-06           21          22   20  ...     1        4        30      19
#
#          stocks  travel  trucker  v-tuber  vehicles  vlog
# 2021-01      11       9       30       17        14     8
# 2021-02      13      11       28       25        23     7
# 2021-03      14      11       29       27        18     5
# 2021-04      12      14       28       27        15     5
# 2021-05      15      12       28       29         5     8
# 2021-06      18      12       29       24        13     3
# 2021-07       5      13       29       22        15     4
# 2021-08       8      10       29       22         5     1
# 2021-09      19       3       29       28         4     6
# 2021-10      15      12       30       28         9     6
# 2021-11      18      13       28       29        10     5
# 2021-12      15      14       29       28        10     5
# 2022-01      16      17       29       28         9     5
# 2022-02       7      16       29       27        10     5
# 2022-03       8      21       29       24        12     3
# 2022-04      10      17       29       26        15     8
# 2022-05      10      13       29       26        19     5
# 2022-06      10       7       29       26        16     2
#
# [18 rows x 31 columns]

# %% [markdown]
# #### 월별 토픽들의 조회수 순위  > 채널명

# %%
month_top_topic_chanel = month_top_topic.copy()
for i, x in month_top_topic_chanel.iterrows():
    for j in range(len(x)):
        topic = x.iloc[j]
        month_top_topic_chanel.iloc[i,j] = [topic, viewed_dfs[topic].loc[i]['채널명']]

month_top_topic_chanel.index = ind
month_top_topic_chanel
# Out:
#                            0                              1   \
# 2021-01    [music, BLACKPINK]        [mukbang, Jane ASMR 제인]
# 2021-02    [music, BLACKPINK]        [mukbang, Jane ASMR 제인]
# 2021-03    [music, BLACKPINK]        [mukbang, Jane ASMR 제인]
# 2021-04  [music, HYBE LABELS]                [news, MBCNEWS]
# 2021-05  [music, HYBE LABELS]                [news, MBCNEWS]
# 2021-06  [music, HYBE LABELS]                [news, MBCNEWS]
# 2021-07    [music, BANGTANTV]  [entertainment, Fast cooking]
# 2021-08    [music, BANGTANTV]                  [vlog, 쇼츠갤러리]
# 2021-09    [music, BLACKPINK]      [mukbang, Hongyu ASMR 홍유]
# 2021-10    [music, BLACKPINK]        [mukbang, Jane ASMR 제인]
# 2021-11    [music, BLACKPINK]     [entertainment, BIBO와 장난감]
# 2021-12    [music, BANGTANTV]                [news, MBCNEWS]
# 2022-01    [music, BLACKPINK]                   [news,  YTN]
# 2022-02    [music, BLACKPINK]                   [news,  YTN]
# 2022-03          [news,  YTN]             [music, BLACKPINK]
# 2022-04  [music, HYBE LABELS]                   [news,  YTN]
# 2022-05  [music, HYBE LABELS]                [news, MBCNEWS]
# 2022-06    [music, BANGTANTV]                [news, MBCNEWS]
#
#                                     2                                      3   \
# 2021-01     [entertainment, tvN drama]                     [science, Samsung]
# 2021-02                [news, MBCNEWS]             [entertainment, tvN drama]
# 2021-03                [news, MBCNEWS]   [entertainment, Stop Motion Cooking]
# 2021-04        [mukbang, Jane ASMR 제인]   [entertainment, Stop Motion Cooking]
# 2021-05                 [comedy, CJY中]               [mukbang, Street Foodie]
# 2021-06       [mukbang, Street Foodie]                  [vlog, 구독자90,000명만들기]
# 2021-07                [news, MBCNEWS]                [mukbang, Jane ASMR 제인]
# 2021-08                [news, MBCNEWS]  [science, 새로운거신기한거재밌는거 NewAmazingFun]
# 2021-09                [news, MBCNEWS]           [travel, Imagine your Korea]
# 2021-10                [news, MBCNEWS]               [entertainment, Mnet TV]
# 2021-11                   [news,  YTN]                [mukbang, Jane ASMR 제인]
# 2021-12     [entertainment, BIBO와 장난감]                     [gaming, 계향쓰 GH'S]
# 2022-01       [howto, ROOKIE MING 루키밍]                [mukbang, Jane ASMR 제인]
# 2022-02            [science, Ok Drama]              [mukbang, Hongyu ASMR 홍유]
# 2022-03            [science, Ok Drama]                          [vlog, 진성호방송]
# 2022-04            [science, Ok Drama]                         [comedy, 옥이튜브]
# 2022-05       [science, ox_zung / 원정맨]              [mukbang, Hongyu ASMR 홍유]
# 2022-06  [vlog, [1분예능] 재미있고 감동적인 1분영상]              [mukbang, Hongyu ASMR 홍유]
#
#                                     4                                5   \
# 2021-01     [education, 스위트티비 SweetTV]                  [news, MBCNEWS]
# 2021-02    [education, 핑크퐁 (인기 동요・동화)]               [gaming, 계향쓰 GH'S]
# 2021-03     [education, 스위트티비 SweetTV]                    [vlog, 진성호방송]
# 2021-04     [education, 스위트티비 SweetTV]                    [vlog, 진성호방송]
# 2021-05  [entertainment, 트리라인treeline]  [vehicles, Hankook Tire Global]
# 2021-06  [entertainment, Fast cooking]             [howto, YogaHoliday]
# 2021-07     [vlog, 짧은 영상 shorts video]                   [stocks, 엠빅뉴스]
# 2021-08        [mukbang, Jane ASMR 제인]               [vehicles, 한문철 TV]
# 2021-09             [vehicles, 한문철 TV]       [entertainment, tvN D ENT]
# 2021-10                   [film, 소맥거핀]           [howto, 쇼츠갤러리 tiktok ]
# 2021-11             [science, Samsung]                    [vlog, 진성호방송]
# 2021-12      [mukbang, Hongyu ASMR 홍유]                    [vlog, 진성호방송]
# 2022-01             [gaming, 계향쓰 GH'S]                    [vlog, 진성호방송]
# 2022-02             [gaming, 계향쓰 GH'S]                    [vlog, 진성호방송]
# 2022-03             [gaming, 계향쓰 GH'S]        [mukbang, Hongyu ASMR 홍유]
# 2022-04        [mukbang, Jane ASMR 제인]               [gaming, 계향쓰 GH'S]
# 2022-05             [gaming, 계향쓰 GH'S]             [vlog, Jᴇᴏɴɪᴄs♥︎방탄°]
# 2022-06       [science, ox_zung / 원정맨]               [gaming, 계향쓰 GH'S]
#
#                                                6   \
# 2021-01  [animals, SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!]
# 2021-02  [animals, SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!]
# 2021-03  [animals, SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!]
# 2021-04                        [gaming, 계향쓰 GH'S]
# 2021-05                        [gaming, 계향쓰 GH'S]
# 2021-06                            [comedy, CJY中]
# 2021-07                        [gaming, 계향쓰 GH'S]
# 2021-08               [education, 핑크퐁 (인기 동요・동화)]
# 2021-09                             [vlog, 진성호방송]
# 2021-10                             [vlog, 진성호방송]
# 2021-11                        [gaming, 계향쓰 GH'S]
# 2021-12               [education, 핑크퐁 (인기 동요・동화)]
# 2022-01                [entertainment, BIBO와 장난감]
# 2022-02                      [howto, jenny slime]
# 2022-03                            [howto, 힐링 쇼츠]
# 2022-04                      [entertainment, 옐언니]
# 2022-05            [entertainment, Lala and Lulu]
# 2022-06                       [howto, 5 분 Tricks]
#
#                                                7   \
# 2021-01                        [gaming, 계향쓰 GH'S]
# 2021-02                             [vlog, 진성호방송]
# 2021-03                        [science, Samsung]
# 2021-04  [animals, SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!]
# 2021-05  [animals, SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!]
# 2021-06                        [gaming, 계향쓰 GH'S]
# 2021-07                        [comedy, 대륙판눈요기TV]
# 2021-08      [entertainment, Stop Motion Cooking]
# 2021-09               [education, 핑크퐁 (인기 동요・동화)]
# 2021-10                        [science, Samsung]
# 2021-11               [education, 핑크퐁 (인기 동요・동화)]
# 2021-12                  [howto, ROOKIE MING 루키밍]
# 2022-01                        [science, Samsung]
# 2022-02                            [stocks, 엠빅뉴스]
# 2022-03                [entertainment, BIBO와 장난감]
# 2022-04                      [howto, jenny slime]
# 2022-05                             [comedy, 밈박스]
# 2022-06              [travel, Imagine your Korea]
#
#                                                8   \
# 2021-01                             [vlog, 진성호방송]
# 2021-02                   [cover-song, JFlaMusic]
# 2021-03                        [gaming, 계향쓰 GH'S]
# 2021-04                        [science, Samsung]
# 2021-05                         [vlog, NCT DREAM]
# 2021-06  [animals, SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!]
# 2021-07               [education, 핑크퐁 (인기 동요・동화)]
# 2021-08                            [stocks, 엠빅뉴스]
# 2021-09     [science, 새로운거신기한거재밌는거 NewAmazingFun]
# 2021-10               [education, 핑크퐁 (인기 동요・동화)]
# 2021-11                [comedy, 가나쌍둥이Ghana Twins]
# 2021-12                  [cooking, 찐푸드 JJin Food]
# 2022-01               [education, 핑크퐁 (인기 동요・동화)]
# 2022-02               [education, 핑크퐁 (인기 동요・동화)]
# 2022-03                     [stocks, MTN 머니투데이방송]
# 2022-04                      [vlog, Jᴇᴏɴɪᴄs♥︎방탄°]
# 2022-05                             [film, 부산따쟁이]
# 2022-06                [entertainment, 뚝딱 상식 뚝배기]
#
#                                       9   ...                              21  \
# 2021-01      [travel, 푸드킹덤 Food Kingdom]  ...                  [camping, nan]
# 2021-02                       [film, 짤툰]  ...         [body-building, 피지컬갤러리]
# 2021-03           [cover-dance, ARTBEAT]  ...         [body-building, 피지컬갤러리]
# 2021-04                  [sports, SPOTV]  ...   [home_workout, Thankyou BUBU]
# 2021-05      [education, 핑크퐁 (인기 동요・동화)]  ...        [makeup, 스마일밤 Smile Bam]
# 2021-06      [education, 핑크퐁 (인기 동요・동화)]  ...          [home_workout, 피지컬갤러리]
# 2021-07             [howto, YogaHoliday]  ...                      [cat, 크집사]
# 2021-08         [howto, ROOKIE MING 루키밍]  ...            [dog, [THE SOY]루퐁이네]
# 2021-09         [howto, ROOKIE MING 루키밍]  ...         [cover-song, JFlaMusic]
# 2021-10               [vehicles, 한문철 TV]  ...  [fashion, 신의손이선생 - DIY edigna]
# 2021-11         [howto, ROOKIE MING 루키밍]  ...          [cover-dance, ARTBEAT]
# 2021-12       [comedy, 가나쌍둥이Ghana Twins]  ...         [cover-song, JFlaMusic]
# 2022-01               [vehicles, 한문철 TV]  ...            [body-building, 박승현]
# 2022-02  [entertainment, TREASURE (트레저)]  ...             [home_workout, 박승현]
# 2022-03      [education, 핑크퐁 (인기 동요・동화)]  ...     [travel, 푸드킹덤 Food Kingdom]
# 2022-04      [education, 핑크퐁 (인기 동요・동화)]  ...  [fashion, 신의손이선생 - DIY edigna]
# 2022-05              [howto, 5 분 Tricks]  ...                 [sports, 이스타TV]
# 2022-06         [film, 리뷰타임 Review Time]  ...          [cover-dance, ARTBEAT]
#
#                                      22                              23  \
# 2021-01                      [cat, nan]                  [cooking, nan]
# 2021-02       [baking, Boone Bake분 베이크]              [vehicles, 한문철 TV]
# 2021-03          [home_workout, 피지컬갤러리]       [baking, Boone Bake분 베이크]
# 2021-04         [body-building, 피지컬갤러리]              [fashion, 깡스타일리스트]
# 2021-05            [body-building, 지피티]          [home_workout, 피지컬갤러리]
# 2021-06       [cat, 밀키복이탄이MilkyBokiTan]         [makeup, 진절미 Jinjeolme]
# 2021-07         [v-tuber, 오리고기 ORIGOGI]             [baking, 서담 seodam]
# 2021-08         [v-tuber, 오리고기 ORIGOGI]                 [camping, 캠핑제국]
# 2021-09                      [cat, 시멘트]                 [camping, 승우아빠]
# 2021-10      [cover-dance, 땡깡DanceKang]         [body-building, 피지컬갤러리]
# 2021-11                      [cat, 시멘트]     [body-building, MBC every1]
# 2021-12              [lookbook, free지아]         [fashion, tvN D STUDIO]
# 2022-01             [home_workout, 박승현]         [cover-song, JFlaMusic]
# 2022-02  [cat, 스튜디오 와플 - STUDIO WAFFLE]         [cover-song, JFlaMusic]
# 2022-03      [cover-dance, 땡깡DanceKang]         [cover-song, JFlaMusic]
# 2022-04   [dog, 꽁냥백과-Animal Dictionary]         [cover-song, JFlaMusic]
# 2022-05   [dog, 꽁냥백과-Animal Dictionary]  [fashion, 신의손이선생 - DIY edigna]
# 2022-06         [cover-song, JFlaMusic]  [fashion, 신의손이선생 - DIY edigna]
#
#                                     24  \
# 2021-01             [cover-dance, nan]
# 2021-02               [fashion, 핏더사이즈]
# 2021-03      [fashion, TRB 트렌드 리뷰 브랜드]
# 2021-04    [baking, Cooking tree 쿠킹트리]
# 2021-05                [camping, 은하캠핑]
# 2021-06        [v-tuber, 오리고기 ORIGOGI]
# 2021-07  [home_workout, Thankyou BUBU]
# 2021-08  [home_workout, Thankyou BUBU]
# 2021-09            [lookbook, 깡스타일리스트]
# 2021-10         [home_workout, 피지컬갤러리]
# 2021-11         [home_workout, 피지컬갤러리]
# 2021-12     [baking, 식탁일기 table diary]
# 2022-01                     [cat, 시멘트]
# 2022-02         [cover-dance, ARTBEAT]
# 2022-03       [v-tuber, 케이맨 King Kman]
# 2022-04                  [cat, 크림히어로즈]
# 2022-05                  [cat, 크림히어로즈]
# 2022-06            [lookbook, 깡스타일리스트]
#
#                                                       25  \
# 2021-01                                [cover-song, nan]
# 2021-02                             [v-tuber, 아구이뽀 A924]
# 2021-03                                  [camping, 캠핑제국]
# 2021-04                                  [camping, 캠핑제국]
# 2021-05                               [fashion, 깡스타일리스트]
# 2021-06                               [fashion, 깡스타일리스트]
# 2021-07  [body-building, 헬창TV Korea Fitness HellchangTV]
# 2021-08                             [body-building, 지피티]
# 2021-09                    [baking, 조꽁드Joconde's baking]
# 2021-10                              [lookbook, 깡스타일리스트]
# 2021-11                              [lookbook, 깡스타일리스트]
# 2021-12                          [body-building, 피지컬갤러리]
# 2022-01                            [camping, MBC every1]
# 2022-02                              [lookbook, 깡스타일리스트]
# 2022-03                   [fashion, 신의손이선생 - DIY edigna]
# 2022-04                              [lookbook, 깡스타일리스트]
# 2022-05                              [lookbook, 깡스타일리스트]
# 2022-06                                    [cat, 크림히어로즈]
#
#                                          26                             27  \
# 2021-01                          [dog, nan]                 [fashion, nan]
# 2021-02             [camping, Rirang OnAir]      [lookbook, 소신사장 SoshinTV]
# 2021-03              [lookbook, 뀨tv kkyutv]           [v-tuber, 아구이뽀 A924]
# 2021-04         [lookbook, 발리비키 - BALIBIKI]                  [v-tuber, 요극]
# 2021-05         [baking, Cooking tree 쿠킹트리]         [lookbook, 뀨tv kkyutv]
# 2021-06                     [camping, 캠핑제국]    [baking, Cooking tree 쿠킹트리]
# 2021-07                  [fashion, 깡스타일리스트]                [camping, 캠핑제국]
# 2021-08      [fashion, 신의손이선생 - DIY edigna]            [lookbook, 깡스타일리스트]
# 2021-09  [home_workout, 꽃빵 TV GGotBBang TV]        [body-building, 피지컬갤러리]
# 2021-10                     [camping, 캠핑제국]    [baking, Cooking tree 쿠킹트리]
# 2021-11             [camping, Rirang OnAir]  [baking, 조꽁드Joconde's baking]
# 2021-12              [home_workout, 피지컬갤러리]          [camping, MBC every1]
# 2022-01              [cover-dance, ARTBEAT]    [baking, Cooking tree 쿠킹트리]
# 2022-02                     [camping, 캠핑제국]             [v-tuber, 아이네 INE]
# 2022-03          [baking, 식탁일기 table diary]            [lookbook, 깡스타일리스트]
# 2022-04                  [v-tuber, 아이네 INE]           [camping, 부산여자하쿠짱TV]
# 2022-05                  [v-tuber, 아이네 INE]      [baking, Boone Bake분 베이크]
# 2022-06               [v-tuber, 비챤 VIichan]     [baking, 식탁일기 table diary]
#
#                                     28                                 29  \
# 2021-01            [home_workout, nan]                       [howto, nan]
# 2021-02      [trucker, 트럭커 디젤집시의 Vlog]                [sneakers, 와디의 신발장]
# 2021-03            [sneakers, 와디의 신발장]                    [trucker, 군복남자]
# 2021-04                [trucker, 군복남자]                [sneakers, 와디의 신발장]
# 2021-05                 [trucker, 권마키]           [v-tuber, 홀로라이브KR 번역&자막]
# 2021-06         [lookbook, 뀨tv kkyutv]                   [trucker, 빠꾸왕간디]
# 2021-07       [lookbook, 디테일 LookBook]                     [trucker, 권마키]
# 2021-08  [baking, 조꽁드Joconde's baking]                   [trucker, 빠꾸왕간디]
# 2021-09            [v-tuber, 번역하는 댕댕이]                     [trucker, 권마키]
# 2021-10            [v-tuber, 번역하는 댕댕이]                   [sneakers, 하빠TV]
# 2021-11                 [trucker, 권마키]          [v-tuber, 징버거 JINGBURGER]
# 2021-12             [v-tuber, 아이네 INE]                     [trucker, 권마키]
# 2022-01             [v-tuber, 아이네 INE]                     [trucker, 권마키]
# 2022-02    [baking, Cooking tree 쿠킹트리]                     [trucker, 권마키]
# 2022-03        [camping, Rirang OnAir]                     [trucker, 권마키]
# 2022-04    [baking, Cooking tree 쿠킹트리]                     [trucker, 권마키]
# 2022-05                [camping, 캠핑제국]                     [trucker, 권마키]
# 2022-06        [camping, Rirang OnAir]  [trucker, 륭TV Amazing Technology]
#
#                                  30
# 2021-01              [trucker, nan]
# 2021-02                [howto, nan]
# 2021-03                [howto, nan]
# 2021-04                [howto, nan]
# 2021-05         [sneakers, 와디의 신발장]
# 2021-06         [sneakers, 와디의 신발장]
# 2021-07         [sneakers, 와디의 신발장]
# 2021-08  [sneakers, 하성운 HASUNGWOON]
# 2021-09         [sneakers, 와디의 신발장]
# 2021-10              [trucker, 권마키]
# 2021-11         [sneakers, 와디의 신발장]
# 2021-12         [sneakers, 와디의 신발장]
# 2022-01         [sneakers, 와디의 신발장]
# 2022-02         [sneakers, 와디의 신발장]
# 2022-03            [sneakers, 하빠TV]
# 2022-04            [sneakers, 하빠TV]
# 2022-05         [sneakers, 와디의 신발장]
# 2022-06         [sneakers, 와디의 신발장]
#
# [18 rows x 31 columns]

# %% [markdown]
# 채널명 별 월 순위 합 구하기

# %%
ranks = dict()
for col in month_top_topic_chanel.columns:
    for ch in month_top_topic_chanel[col]:
        print(ch)
        try:
            ranks[ch[1]][1] += col
        except:
            ranks[ch[1]] = [ch[0], col]
            
ranks
# Out:
# ['music', 'BLACKPINK']
# ['music', 'BLACKPINK']
# ['music', 'BLACKPINK']
# ['music', 'HYBE LABELS']
# ['music', 'HYBE LABELS']
# ['music', 'HYBE LABELS']
# ['music', 'BANGTANTV']
# ['music', 'BANGTANTV']
# ['music', 'BLACKPINK']
# ['music', 'BLACKPINK']
# ['music', 'BLACKPINK']
# ['music', 'BANGTANTV']
# ['music', 'BLACKPINK']
# ['music', 'BLACKPINK']
# ['news', ' YTN']
# ['music', 'HYBE LABELS']
# ['music', 'HYBE LABELS']
# ['music', 'BANGTANTV']
# ['mukbang', 'Jane ASMR 제인']
# ['mukbang', 'Jane ASMR 제인']
# ['mukbang', 'Jane ASMR 제인']
# ['news', 'MBCNEWS']
# ['news', 'MBCNEWS']
# ['news', 'MBCNEWS']
# ['entertainment', 'Fast cooking']
# ['vlog', '쇼츠갤러리']
# ['mukbang', 'Hongyu ASMR 홍유']
# ['mukbang', 'Jane ASMR 제인']
# ['entertainment', 'BIBO와 장난감']
# ['news', 'MBCNEWS']
# ['news', ' YTN']
# ['news', ' YTN']
# ['music', 'BLACKPINK']
# ['news', ' YTN']
# ['news', 'MBCNEWS']
# ['news', 'MBCNEWS']
# ['entertainment', 'tvN drama']
# ['news', 'MBCNEWS']
# ['news', 'MBCNEWS']
# ['mukbang', 'Jane ASMR 제인']
# ['comedy', 'CJY中']
# ['mukbang', 'Street Foodie']
# ['news', 'MBCNEWS']
# ['news', 'MBCNEWS']
# ['news', 'MBCNEWS']
# ['news', 'MBCNEWS']
# ['news', ' YTN']
# ['entertainment', 'BIBO와 장난감']
# ['howto', 'ROOKIE MING 루키밍']
# ['science', 'Ok Drama']
# ['science', 'Ok Drama']
# ['science', 'Ok Drama']
# ['science', 'ox_zung / 원정맨']
# ['vlog', '[1분예능] 재미있고 감동적인 1분영상']
# ['science', 'Samsung']
# ['entertainment', 'tvN drama']
# ['entertainment', 'Stop Motion Cooking']
# ['entertainment', 'Stop Motion Cooking']
# ['mukbang', 'Street Foodie']
# ['vlog', '구독자90,000명만들기']
# ['mukbang', 'Jane ASMR 제인']
# ['science', '새로운거신기한거재밌는거 NewAmazingFun']
# ['travel', 'Imagine your Korea']
# ['entertainment', 'Mnet TV']
# ['mukbang', 'Jane ASMR 제인']
# ['gaming', "계향쓰 GH'S"]
# ['mukbang', 'Jane ASMR 제인']
# ['mukbang', 'Hongyu ASMR 홍유']
# ['vlog', '진성호방송']
# ['comedy', '옥이튜브']
# ['mukbang', 'Hongyu ASMR 홍유']
# ['mukbang', 'Hongyu ASMR 홍유']
# ['education', '스위트티비 SweetTV']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['education', '스위트티비 SweetTV']
# ['education', '스위트티비 SweetTV']
# ['entertainment', '트리라인treeline']
# ['entertainment', 'Fast cooking']
# ['vlog', '짧은 영상 shorts video']
# ['mukbang', 'Jane ASMR 제인']
# ['vehicles', '한문철 TV']
# ['film', '소맥거핀']
# ['science', 'Samsung']
# ['mukbang', 'Hongyu ASMR 홍유']
# ['gaming', "계향쓰 GH'S"]
# ['gaming', "계향쓰 GH'S"]
# ['gaming', "계향쓰 GH'S"]
# ['mukbang', 'Jane ASMR 제인']
# ['gaming', "계향쓰 GH'S"]
# ['science', 'ox_zung / 원정맨']
# ['news', 'MBCNEWS']
# ['gaming', "계향쓰 GH'S"]
# ['vlog', '진성호방송']
# ['vlog', '진성호방송']
# ['vehicles', 'Hankook Tire Global']
# ['howto', 'YogaHoliday']
# ['stocks', '엠빅뉴스']
# ['vehicles', '한문철 TV']
# ['entertainment', 'tvN D ENT']
# ['howto', '쇼츠갤러리 tiktok ']
# ['vlog', '진성호방송']
# ['vlog', '진성호방송']
# ['vlog', '진성호방송']
# ['vlog', '진성호방송']
# ['mukbang', 'Hongyu ASMR 홍유']
# ['gaming', "계향쓰 GH'S"]
# ['vlog', 'Jᴇᴏɴɪᴄs♥︎방탄°']
# ['gaming', "계향쓰 GH'S"]
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['gaming', "계향쓰 GH'S"]
# ['gaming', "계향쓰 GH'S"]
# ['comedy', 'CJY中']
# ['gaming', "계향쓰 GH'S"]
# ['education', '핑크퐁 (인기 동요・동화)']
# ['vlog', '진성호방송']
# ['vlog', '진성호방송']
# ['gaming', "계향쓰 GH'S"]
# ['education', '핑크퐁 (인기 동요・동화)']
# ['entertainment', 'BIBO와 장난감']
# ['howto', 'jenny slime']
# ['howto', '힐링 쇼츠']
# ['entertainment', '옐언니']
# ['entertainment', 'Lala and Lulu']
# ['howto', '5 분 Tricks']
# ['gaming', "계향쓰 GH'S"]
# ['vlog', '진성호방송']
# ['science', 'Samsung']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['gaming', "계향쓰 GH'S"]
# ['comedy', '대륙판눈요기TV']
# ['entertainment', 'Stop Motion Cooking']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['science', 'Samsung']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['howto', 'ROOKIE MING 루키밍']
# ['science', 'Samsung']
# ['stocks', '엠빅뉴스']
# ['entertainment', 'BIBO와 장난감']
# ['howto', 'jenny slime']
# ['comedy', '밈박스']
# ['travel', 'Imagine your Korea']
# ['vlog', '진성호방송']
# ['cover-song', 'JFlaMusic']
# ['gaming', "계향쓰 GH'S"]
# ['science', 'Samsung']
# ['vlog', 'NCT DREAM']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['stocks', '엠빅뉴스']
# ['science', '새로운거신기한거재밌는거 NewAmazingFun']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['comedy', '가나쌍둥이Ghana Twins']
# ['cooking', '찐푸드 JJin Food']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['stocks', 'MTN 머니투데이방송']
# ['vlog', 'Jᴇᴏɴɪᴄs♥︎방탄°']
# ['film', '부산따쟁이']
# ['entertainment', '뚝딱 상식 뚝배기']
# ['travel', '푸드킹덤 Food Kingdom']
# ['film', '짤툰']
# ['cover-dance', 'ARTBEAT']
# ['sports', 'SPOTV']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['howto', 'YogaHoliday']
# ['howto', 'ROOKIE MING 루키밍']
# ['howto', 'ROOKIE MING 루키밍']
# ['vehicles', '한문철 TV']
# ['howto', 'ROOKIE MING 루키밍']
# ['comedy', '가나쌍둥이Ghana Twins']
# ['vehicles', '한문철 TV']
# ['entertainment', 'TREASURE (트레저)']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['howto', '5 분 Tricks']
# ['film', '리뷰타임 Review Time']
# ['film', '짤툰']
# ['sports', 'SPOTV']
# ['sports', 'SPOTV']
# ['cat', '금수강산Kpetworld']
# ['science', 'Samsung']
# ['cooking', '찐푸드 JJin Food']
# ['cooking', '찐푸드 JJin Food']
# ['travel', '푸드킹덤 Food Kingdom']
# ['fashion', '신의손이선생 - DIY edigna']
# ['comedy', 'shorts시청']
# ['vehicles', '한문철 TV']
# ['vehicles', '한문철 TV']
# ['makeup', 'free지아']
# ['vehicles', '한문철 TV']
# ['makeup', '스마일밤 Smile Bam']
# ['stocks', '엠빅뉴스']
# ['stocks', '엠빅뉴스']
# ['stocks', '엠빅뉴스']
# ['stocks', '삼프로TV_경제의신과함께']
# ['travel', '푸드킹덤 Food Kingdom']
# ['travel', '푸드킹덤 Food Kingdom']
# ['dog', '금수강산Kpetworld']
# ['howto', 'Yummy Waffle 야미와플']
# ['film', 'MOOMOO STUDIO']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['gaming', '탁주 TV']
# ['gaming', "계향쓰 GH'S"]
# ['gaming', "계향쓰 GH'S"]
# ['fashion', '신의손이선생 - DIY edigna']
# ['science', 'Seegene 씨젠']
# ['lookbook', 'free지아']
# ['makeup', '스마일밤 Smile Bam']
# ['comedy', '밈박스']
# ['makeup', '스마일밤 Smile Bam']
# ['cover-song', 'SY TALENT ENTERTAINMENT']
# ['makeup', '스마일밤 Smile Bam']
# ['sports', 'SPOTV']
# ['dog', '[THE SOY]루퐁이네']
# ['film', '짤툰']
# ['stocks', '삼프로TV_경제의신과함께']
# ['travel', '푸드킹덤 Food Kingdom']
# ['travel', '피기보이 PiggyBoy']
# ['film', 'Ace Art 에이스 아트']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['cooking', '찐푸드 JJin Food']
# ['travel', "I'm perfect"]
# ['film', '소맥거핀']
# ['animals', '[THE SOY]루퐁이네']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['cooking', '푸드클럽 The Food Club']
# ['vehicles', '한문철 TV']
# ['film', '짤툰']
# ['education', 'CoCosToy 꼬꼬스토이']
# ['education', '핑크퐁 (인기 동요・동화)']
# ['comedy', '사나이 김기훈']
# ['stocks', '삼프로TV_경제의신과함께']
# ['cover-song', 'JFlaMusic']
# ['cover-song', 'JFlaMusic']
# ['sports', '스포츠타임']
# ['vehicles', '한문철 TV']
# ['travel', '야미보이 Yummyboy']
# ['comedy', '대륙판눈요기TV']
# ['comedy', '가나쌍둥이Ghana Twins']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['travel', 'Soon Films 순필름']
# ['dog', '[THE SOY]루퐁이네']
# ['cooking', '1분요리 뚝딱이형']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['cooking', '1분요리 뚝딱이형']
# ['cooking', '1분요리 뚝딱이형']
# ['travel', 'Imagine your Korea']
# ['home_workout', '박승현']
# ['vehicles', '한문철 TV']
# ['cover-dance', 'ARTBEAT']
# ['stocks', '삼프로TV_경제의신과함께']
# ['travel', '야미보이 Yummyboy']
# ['cover-song', 'JFlaMusic']
# ['cover-dance', 'ARTBEAT']
# ['dog', '[THE SOY]루퐁이네']
# ['sports', '펀한이슈']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['cooking', '찐푸드 JJin Food']
# ['makeup', '스마일밤 Smile Bam']
# ['travel', '찐푸드 JJin Food']
# ['fashion', '신의손이선생 - DIY edigna']
# ['comedy', '진짜갱스터']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['cover-dance', 'ARTBEAT']
# ['body-building', '박승현']
# ['makeup', "자몽's beauty"]
# ['science', 'Samsung']
# ['cooking', 'SIO ASMR']
# ['vehicles', '한문철 TV']
# ['stocks', '나몰라패밀리 핫쇼']
# ['science', 'Samsung']
# ['vehicles', '한문철 TV']
# ['film', '짤툰']
# ['sports', '별의별것']
# ['stocks', '엠빅뉴스']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['stocks', '엠빅뉴스']
# ['comedy', '세얼간이3idiots']
# ['fashion', '신의손이선생 - DIY edigna']
# ['body-building', '박승현']
# ['vehicles', '한문철 TV']
# ['home_workout', '박승현']
# ['comedy', '밈박스']
# ['lookbook', '뀨tv kkyutv']
# ['cooking', '승우아빠']
# ['dog', '[THE SOY]루퐁이네']
# ['cover-dance', 'ARTBEAT']
# ['film', '짤툰']
# ['sports', '팀일루션 노성율 - TEAM1LLUSION']
# ['sports', '김종국 GYM JONG KOOK']
# ['cooking', '찐푸드 JJin Food']
# ['film', '짤툰']
# ['sports', '이스타TV']
# ['cooking', '1분요리 뚝딱이형']
# ['film', '짤툰']
# ['stocks', 'MTN 머니투데이방송']
# ['travel', 'Imagine your Korea']
# ['home_workout', '박승현']
# ['cover-dance', 'ARTBEAT']
# ['body-building', '박승현']
# ['vehicles', 'road Chin']
# ['v-tuber', 'ShiningStar']
# ['comedy', '사나이 김기훈']
# ['makeup', '스마일밤 Smile Bam']
# ['cooking', 'ETTV 이티티비']
# ['cover-dance', 'ARTBEAT']
# ['cover-song', 'JFlaMusic']
# ['cover-song', 'JFlaMusic']
# ['cover-song', 'JFlaMusic']
# ['dog', '[THE SOY]루퐁이네']
# ['makeup', '스마일밤 Smile Bam']
# ['sports', '이스타TV']
# ['makeup', '스마일밤 Smile Bam']
# ['travel', '푸드클럽 The Food Club']
# ['sports', '꽉잡아윤기-Kwakyoongy']
# ['film', '짤툰']
# ['travel', '야미보이 Yummyboy']
# ['makeup', '스마일밤 Smile Bam']
# ['animals', 'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!']
# ['sneakers', '하빠TV']
# ['makeup', '스마일밤 Smile Bam']
# ['vehicles', '한문철 TV']
# ['makeup', '스마일밤 Smile Bam']
# ['cooking', '주부나라']
# ['stocks', 'MTN 머니투데이방송']
# ['makeup', '스마일밤 Smile Bam']
# ['cat', '크집사']
# ['makeup', '스마일밤 Smile Bam']
# ['cat', '시멘트']
# ['stocks', '엠빅뉴스']
# ['sports', '이스타TV']
# ['film', '짤툰']
# ['dog', '시멘트']
# ['sports', '박승현']
# ['sports', '슛스케 ShootSke']
# ['cooking', '요리용디 Yori Yongd']
# ['cooking', '찐푸드 JJin Food']
# ['baking', nan]
# ['cat', '크림히어로즈']
# ['cat', '밀키복이탄이MilkyBokiTan']
# ['comedy', '진우와 해티']
# ['dog', '밀키복이탄이MilkyBokiTan']
# ['dog', '[THE SOY]루퐁이네']
# ['cover-dance', 'ARTBEAT']
# ['cover-dance', 'ARTBEAT']
# ['stocks', '삼프로TV_경제의신과함께']
# ['dog', '시멘트']
# ['dog', '[THE SOY]루퐁이네']
# ['cat', '시멘트']
# ['sports', '이스타TV']
# ['film', '스마일밤 Smile Bam']
# ['dog', '스튜디오 와플 - STUDIO WAFFLE']
# ['body-building', '박승현']
# ['vehicles', '한문철 TV']
# ['sports', '박승현']
# ['body-building', nan]
# ['home_workout', '피지컬갤러리']
# ['comedy', '피식대학Psick Univ']
# ['film', 'Hwang jae ahn fictions']
# ['cat', '밀키복이탄이MilkyBokiTan']
# ['body-building', '피지컬갤러리']
# ['science', 'ITSub잇섭']
# ['makeup', '스마일밤 Smile Bam']
# ['cover-dance', 'ARTBEAT']
# ['cover-song', 'JFlaMusic']
# ['cover-song', 'JFlaMusic']
# ['cover-dance', 'ARTBEAT']
# ['dog', '[THE SOY]루퐁이네']
# ['body-building', '박승현']
# ['cat', '스튜디오 와플 - STUDIO WAFFLE']
# ['home_workout', '박승현']
# ['animals', 'KBS동물티비 : 애니멀포유 animal4u']
# ['dog', '애니멀플래닛']
# ['camping', nan]
# ['body-building', '피지컬갤러리']
# ['body-building', '피지컬갤러리']
# ['home_workout', 'Thankyou BUBU']
# ['makeup', '스마일밤 Smile Bam']
# ['home_workout', '피지컬갤러리']
# ['cat', '크집사']
# ['dog', '[THE SOY]루퐁이네']
# ['cover-song', 'JFlaMusic']
# ['fashion', '신의손이선생 - DIY edigna']
# ['cover-dance', 'ARTBEAT']
# ['cover-song', 'JFlaMusic']
# ['body-building', '박승현']
# ['home_workout', '박승현']
# ['travel', '푸드킹덤 Food Kingdom']
# ['fashion', '신의손이선생 - DIY edigna']
# ['sports', '이스타TV']
# ['cover-dance', 'ARTBEAT']
# ['cat', nan]
# ['baking', 'Boone Bake분 베이크']
# ['home_workout', '피지컬갤러리']
# ['body-building', '피지컬갤러리']
# ['body-building', '지피티']
# ['cat', '밀키복이탄이MilkyBokiTan']
# ['v-tuber', '오리고기 ORIGOGI']
# ['v-tuber', '오리고기 ORIGOGI']
# ['cat', '시멘트']
# ['cover-dance', '땡깡DanceKang']
# ['cat', '시멘트']
# ['lookbook', 'free지아']
# ['home_workout', '박승현']
# ['cat', '스튜디오 와플 - STUDIO WAFFLE']
# ['cover-dance', '땡깡DanceKang']
# ['dog', '꽁냥백과-Animal Dictionary']
# ['dog', '꽁냥백과-Animal Dictionary']
# ['cover-song', 'JFlaMusic']
# ['cooking', nan]
# ['vehicles', '한문철 TV']
# ['baking', 'Boone Bake분 베이크']
# ['fashion', '깡스타일리스트']
# ['home_workout', '피지컬갤러리']
# ['makeup', '진절미 Jinjeolme']
# ['baking', '서담 seodam']
# ['camping', '캠핑제국']
# ['camping', '승우아빠']
# ['body-building', '피지컬갤러리']
# ['body-building', 'MBC every1']
# ['fashion', 'tvN D STUDIO']
# ['cover-song', 'JFlaMusic']
# ['cover-song', 'JFlaMusic']
# ['cover-song', 'JFlaMusic']
# ['cover-song', 'JFlaMusic']
# ['fashion', '신의손이선생 - DIY edigna']
# ['fashion', '신의손이선생 - DIY edigna']
# ['cover-dance', nan]
# ['fashion', '핏더사이즈']
# ['fashion', 'TRB 트렌드 리뷰 브랜드']
# ['baking', 'Cooking tree 쿠킹트리']
# ['camping', '은하캠핑']
# ['v-tuber', '오리고기 ORIGOGI']
# ['home_workout', 'Thankyou BUBU']
# ['home_workout', 'Thankyou BUBU']
# ['lookbook', '깡스타일리스트']
# ['home_workout', '피지컬갤러리']
# ['home_workout', '피지컬갤러리']
# ['baking', '식탁일기 table diary']
# ['cat', '시멘트']
# ['cover-dance', 'ARTBEAT']
# ['v-tuber', '케이맨 King Kman']
# ['cat', '크림히어로즈']
# ['cat', '크림히어로즈']
# ['lookbook', '깡스타일리스트']
# ['cover-song', nan]
# ['v-tuber', '아구이뽀 A924']
# ['camping', '캠핑제국']
# ['camping', '캠핑제국']
# ['fashion', '깡스타일리스트']
# ['fashion', '깡스타일리스트']
# ['body-building', '헬창TV Korea Fitness HellchangTV']
# ['body-building', '지피티']
# ['baking', "조꽁드Joconde's baking"]
# ['lookbook', '깡스타일리스트']
# ['lookbook', '깡스타일리스트']
# ['body-building', '피지컬갤러리']
# ['camping', 'MBC every1']
# ['lookbook', '깡스타일리스트']
# ['fashion', '신의손이선생 - DIY edigna']
# ['lookbook', '깡스타일리스트']
# ['lookbook', '깡스타일리스트']
# ['cat', '크림히어로즈']
# ['dog', nan]
# ['camping', 'Rirang OnAir']
# ['lookbook', '뀨tv kkyutv']
# ['lookbook', '발리비키 - BALIBIKI']
# ['baking', 'Cooking tree 쿠킹트리']
# ['camping', '캠핑제국']
# ['fashion', '깡스타일리스트']
# ['fashion', '신의손이선생 - DIY edigna']
# ['home_workout', '꽃빵 TV GGotBBang TV']
# ['camping', '캠핑제국']
# ['camping', 'Rirang OnAir']
# ['home_workout', '피지컬갤러리']
# ['cover-dance', 'ARTBEAT']
# ['camping', '캠핑제국']
# ['baking', '식탁일기 table diary']
# ['v-tuber', '아이네 INE']
# ['v-tuber', '아이네 INE']
# ['v-tuber', '비챤 VIichan']
# ['fashion', nan]
# ['lookbook', '소신사장 SoshinTV']
# ['v-tuber', '아구이뽀 A924']
# ['v-tuber', '요극']
# ['lookbook', '뀨tv kkyutv']
# ['baking', 'Cooking tree 쿠킹트리']
# ['camping', '캠핑제국']
# ['lookbook', '깡스타일리스트']
# ['body-building', '피지컬갤러리']
# ['baking', 'Cooking tree 쿠킹트리']
# ['baking', "조꽁드Joconde's baking"]
# ['camping', 'MBC every1']
# ['baking', 'Cooking tree 쿠킹트리']
# ['v-tuber', '아이네 INE']
# ['lookbook', '깡스타일리스트']
# ['camping', '부산여자하쿠짱TV']
# ['baking', 'Boone Bake분 베이크']
# ['baking', '식탁일기 table diary']
# ['home_workout', nan]
# ['trucker', '트럭커 디젤집시의 Vlog']
# ['sneakers', '와디의 신발장']
# ['trucker', '군복남자']
# ['trucker', '권마키']
# ['lookbook', '뀨tv kkyutv']
# ['lookbook', '디테일 LookBook']
# ['baking', "조꽁드Joconde's baking"]
# ['v-tuber', '번역하는 댕댕이']
# ['v-tuber', '번역하는 댕댕이']
# ['trucker', '권마키']
# ['v-tuber', '아이네 INE']
# ['v-tuber', '아이네 INE']
# ['baking', 'Cooking tree 쿠킹트리']
# ['camping', 'Rirang OnAir']
# ['baking', 'Cooking tree 쿠킹트리']
# ['camping', '캠핑제국']
# ['camping', 'Rirang OnAir']
# ['howto', nan]
# ['sneakers', '와디의 신발장']
# ['trucker', '군복남자']
# ['sneakers', '와디의 신발장']
# ['v-tuber', '홀로라이브KR 번역&자막']
# ['trucker', '빠꾸왕간디']
# ['trucker', '권마키']
# ['trucker', '빠꾸왕간디']
# ['trucker', '권마키']
# ['sneakers', '하빠TV']
# ['v-tuber', '징버거 JINGBURGER']
# ['trucker', '권마키']
# ['trucker', '권마키']
# ['trucker', '권마키']
# ['trucker', '권마키']
# ['trucker', '권마키']
# ['trucker', '권마키']
# ['trucker', '륭TV Amazing Technology']
# ['trucker', nan]
# ['howto', nan]
# ['howto', nan]
# ['howto', nan]
# ['sneakers', '와디의 신발장']
# ['sneakers', '와디의 신발장']
# ['sneakers', '와디의 신발장']
# ['sneakers', '하성운 HASUNGWOON']
# ['sneakers', '와디의 신발장']
# ['trucker', '권마키']
# ['sneakers', '와디의 신발장']
# ['sneakers', '와디의 신발장']
# ['sneakers', '와디의 신발장']
# ['sneakers', '와디의 신발장']
# ['sneakers', '하빠TV']
# ['sneakers', '하빠TV']
# ['sneakers', '와디의 신발장']
# ['sneakers', '와디의 신발장']
# {'BLACKPINK': ['music', 1],
#  'HYBE LABELS': ['music', 0],
#  'BANGTANTV': ['music', 0],
#  ' YTN': ['news', 5],
#  'Jane ASMR 제인': ['mukbang', 23],
#  'MBCNEWS': ['news', 23],
#  'Fast cooking': ['entertainment', 5],
#  '쇼츠갤러리': ['vlog', 1],
#  'Hongyu ASMR 홍유': ['mukbang', 19],
#  'BIBO와 장난감': ['entertainment', 16],
#  'tvN drama': ['entertainment', 5],
#  'CJY中': ['comedy', 8],
#  'Street Foodie': ['mukbang', 5],
#  'ROOKIE MING 루키밍': ['howto', 36],
#  'Ok Drama': ['science', 6],
#  'ox_zung / 원정맨': ['science', 6],
#  '[1분예능] 재미있고 감동적인 1분영상': ['vlog', 2],
#  'Samsung': ['science', 76],
#  'Stop Motion Cooking': ['entertainment', 13],
#  '구독자90,000명만들기': ['vlog', 3],
#  '새로운거신기한거재밌는거 NewAmazingFun': ['science', 11],
#  'Imagine your Korea': ['travel', 39],
#  'Mnet TV': ['entertainment', 3],
#  "계향쓰 GH'S": ['gaming', 102],
#  '진성호방송': ['vlog', 60],
#  '옥이튜브': ['comedy', 3],
#  '스위트티비 SweetTV': ['education', 12],
#  '핑크퐁 (인기 동요・동화)': ['education', 110],
#  '트리라인treeline': ['entertainment', 4],
#  '짧은 영상 shorts video': ['vlog', 4],
#  '한문철 TV': ['vehicles', 201],
#  '소맥거핀': ['film', 16],
#  'Hankook Tire Global': ['vehicles', 5],
#  'YogaHoliday': ['howto', 14],
#  '엠빅뉴스': ['stocks', 98],
#  'tvN D ENT': ['entertainment', 5],
#  '쇼츠갤러리 tiktok ': ['howto', 5],
#  'Jᴇᴏɴɪᴄs♥︎방탄°': ['vlog', 13],
#  'SBS TV동물농장x애니멀봐 공식 유튜브 채널입니다!': ['animals', 175],
#  'jenny slime': ['howto', 13],
#  '힐링 쇼츠': ['howto', 6],
#  '옐언니': ['entertainment', 6],
#  'Lala and Lulu': ['entertainment', 6],
#  '5 분 Tricks': ['howto', 15],
#  '대륙판눈요기TV': ['comedy', 20],
#  '밈박스': ['comedy', 33],
#  'JFlaMusic': ['cover-song', 295],
#  'NCT DREAM': ['vlog', 8],
#  '가나쌍둥이Ghana Twins': ['comedy', 30],
#  '찐푸드 JJin Food': ['cooking', 102],
#  'MTN 머니투데이방송': ['stocks', 42],
#  '부산따쟁이': ['film', 8],
#  '뚝딱 상식 뚝배기': ['entertainment', 8],
#  '푸드킹덤 Food Kingdom': ['travel', 74],
#  '짤툰': ['film', 141],
#  'ARTBEAT': ['cover-dance', 270],
#  'SPOTV': ['sports', 41],
#  'TREASURE (트레저)': ['entertainment', 9],
#  '리뷰타임 Review Time': ['film', 9],
#  '금수강산Kpetworld': ['cat', 21],
#  '신의손이선생 - DIY edigna': ['fashion', 189],
#  'shorts시청': ['comedy', 10],
#  'free지아': ['makeup', 43],
#  '스마일밤 Smile Bam': ['makeup', 257],
#  '삼프로TV_경제의신과함께': ['stocks', 69],
#  'Yummy Waffle 야미와플': ['howto', 11],
#  'MOOMOO STUDIO': ['film', 11],
#  '탁주 TV': ['gaming', 11],
#  'Seegene 씨젠': ['science', 11],
#  'SY TALENT ENTERTAINMENT': ['cover-song', 11],
#  '[THE SOY]루퐁이네': ['dog', 163],
#  '피기보이 PiggyBoy': ['travel', 12],
#  'Ace Art 에이스 아트': ['film', 12],
#  "I'm perfect": ['travel', 12],
#  '푸드클럽 The Food Club': ['cooking', 29],
#  'CoCosToy 꼬꼬스토이': ['education', 12],
#  '사나이 김기훈': ['comedy', 30],
#  '스포츠타임': ['sports', 13],
#  '야미보이 Yummyboy': ['travel', 44],
#  'Soon Films 순필름': ['travel', 13],
#  '1분요리 뚝딱이형': ['cooking', 55],
#  '박승현': ['home_workout', 249],
#  '펀한이슈': ['sports', 14],
#  '진짜갱스터': ['comedy', 14],
#  "자몽's beauty": ['makeup', 15],
#  'SIO ASMR': ['cooking', 15],
#  '나몰라패밀리 핫쇼': ['stocks', 15],
#  '별의별것': ['sports', 15],
#  '세얼간이3idiots': ['comedy', 15],
#  '뀨tv kkyutv': ['lookbook', 97],
#  '승우아빠': ['cooking', 39],
#  '팀일루션 노성율 - TEAM1LLUSION': ['sports', 16],
#  '김종국 GYM JONG KOOK': ['sports', 16],
#  '이스타TV': ['sports', 91],
#  'road Chin': ['vehicles', 16],
#  'ShiningStar': ['v-tuber', 17],
#  'ETTV 이티티비': ['cooking', 17],
#  '꽉잡아윤기-Kwakyoongy': ['sports', 17],
#  '하빠TV': ['sneakers', 107],
#  '주부나라': ['cooking', 18],
#  '크집사': ['cat', 39],
#  '시멘트': ['cat', 142],
#  '슛스케 ShootSke': ['sports', 18],
#  '요리용디 Yori Yongd': ['cooking', 18],
#  nan: ['baking', 384],
#  '크림히어로즈': ['cat', 92],
#  '밀키복이탄이MilkyBokiTan': ['cat', 80],
#  '진우와 해티': ['comedy', 19],
#  '스튜디오 와플 - STUDIO WAFFLE': ['dog', 61],
#  '피지컬갤러리': ['home_workout', 319],
#  '피식대학Psick Univ': ['comedy', 20],
#  'Hwang jae ahn fictions': ['film', 20],
#  'ITSub잇섭': ['science', 20],
#  'KBS동물티비 : 애니멀포유 animal4u': ['animals', 20],
#  '애니멀플래닛': ['dog', 20],
#  'Thankyou BUBU': ['home_workout', 69],
#  'Boone Bake분 베이크': ['baking', 72],
#  '지피티': ['body-building', 47],
#  '오리고기 ORIGOGI': ['v-tuber', 68],
#  '땡깡DanceKang': ['cover-dance', 44],
#  '꽁냥백과-Animal Dictionary': ['dog', 44],
#  '깡스타일리스트': ['fashion', 326],
#  '진절미 Jinjeolme': ['makeup', 23],
#  '서담 seodam': ['baking', 23],
#  '캠핑제국': ['camping', 206],
#  'MBC every1': ['body-building', 75],
#  'tvN D STUDIO': ['fashion', 23],
#  '핏더사이즈': ['fashion', 24],
#  'TRB 트렌드 리뷰 브랜드': ['fashion', 24],
#  'Cooking tree 쿠킹트리': ['baking', 187],
#  '은하캠핑': ['camping', 24],
#  '식탁일기 table diary': ['baking', 77],
#  '케이맨 King Kman': ['v-tuber', 24],
#  '아구이뽀 A924': ['v-tuber', 52],
#  '헬창TV Korea Fitness HellchangTV': ['body-building', 25],
#  "조꽁드Joconde's baking": ['baking', 80],
#  'Rirang OnAir': ['camping', 108],
#  '발리비키 - BALIBIKI': ['lookbook', 26],
#  '꽃빵 TV GGotBBang TV': ['home_workout', 26],
#  '아이네 INE': ['v-tuber', 135],
#  '비챤 VIichan': ['v-tuber', 26],
#  '소신사장 SoshinTV': ['lookbook', 27],
#  '요극': ['v-tuber', 27],
#  '부산여자하쿠짱TV': ['camping', 27],
#  '트럭커 디젤집시의 Vlog': ['trucker', 28],
#  '와디의 신발장': ['sneakers', 386],
#  '군복남자': ['trucker', 57],
#  '권마키': ['trucker', 318],
#  '디테일 LookBook': ['lookbook', 28],
#  '번역하는 댕댕이': ['v-tuber', 56],
#  '홀로라이브KR 번역&자막': ['v-tuber', 29],
#  '빠꾸왕간디': ['trucker', 58],
#  '징버거 JINGBURGER': ['v-tuber', 29],
#  '륭TV Amazing Technology': ['trucker', 29],
#  '하성운 HASUNGWOON': ['sneakers', 30]}

# %%
total_rank_sum = pd.DataFrame(sorted(ranks.items(),key = lambda x : x[1][1]))
total_rank_sum[:30]
# Out:
#                              0                   1
# 0                  HYBE LABELS          [music, 0]
# 1                    BANGTANTV          [music, 0]
# 2                    BLACKPINK          [music, 1]
# 3                        쇼츠갤러리           [vlog, 1]
# 4        [1분예능] 재미있고 감동적인 1분영상           [vlog, 2]
# 5                구독자90,000명만들기           [vlog, 3]
# 6                      Mnet TV  [entertainment, 3]
# 7                         옥이튜브         [comedy, 3]
# 8                 트리라인treeline  [entertainment, 4]
# 9           짧은 영상 shorts video           [vlog, 4]
# 10                         YTN           [news, 5]
# 11                Fast cooking  [entertainment, 5]
# 12                   tvN drama  [entertainment, 5]
# 13               Street Foodie        [mukbang, 5]
# 14         Hankook Tire Global       [vehicles, 5]
# 15                   tvN D ENT  [entertainment, 5]
# 16               쇼츠갤러리 tiktok           [howto, 5]
# 17                    Ok Drama        [science, 6]
# 18               ox_zung / 원정맨        [science, 6]
# 19                       힐링 쇼츠          [howto, 6]
# 20                         옐언니  [entertainment, 6]
# 21               Lala and Lulu  [entertainment, 6]
# 22                        CJY中         [comedy, 8]
# 23                   NCT DREAM           [vlog, 8]
# 24                       부산따쟁이           [film, 8]
# 25                   뚝딱 상식 뚝배기  [entertainment, 8]
# 26              TREASURE (트레저)  [entertainment, 9]
# 27            리뷰타임 Review Time           [film, 9]
# 28                    shorts시청        [comedy, 10]
# 29  새로운거신기한거재밌는거 NewAmazingFun       [science, 11]

# %% [markdown]
# 개인채널이 아닌 아티스트, 방송채널이 대부분

# %%
plt.figure(figsize=(16,6))
plt.xticks(range(len(ind)), ind, rotation=80)
for topic in topics[1:]:
    r = topic_rank_df[topic]
    plt.plot(range(18),r,
             'o--', color = colors[topics.index(topic)])
    
    plt.text(-1,r.iloc[0] , topic, fontsize=14, color=colors[topics.index(topic)])

# %% [markdown]
# - trucker, sneakers 분야는 계속 하위권을 유지중
# - music, mukbang, news, entertainment 분야는 상위권을 유지중

# %% [markdown]
# 선택 분야별 순위 변동 비교

# %%
plt.figure(figsize=(16,6))
plt.xticks(range(len(ind)), ind, rotation=80)
for topic in selected_topic:
    r = topic_rank_df[topic]
    plt.plot(range(18),r,
             'o--', color = colors[topics.index(topic)])
    
plt.legend(selected_topic,loc = 2)

# %% [markdown]
# - 게임 분야가 21년 12월 이후부터 높은 순위를 유지중
# - 과학 분야는 순위 변동이 크다
# - 먹방 분야는 지속적으로 높은 순위를 보인다.

# %% [markdown]
# 선택한 분야의 채널을 정해 조원 별로 다양한 관점으로 분석 진행
# 한문철TV(vehicles), 스마일밤 Smile Bam(makeup), Jane ASMR 제인(mukbang), 계향쓰 GH's(gaming), ITSub(science)
