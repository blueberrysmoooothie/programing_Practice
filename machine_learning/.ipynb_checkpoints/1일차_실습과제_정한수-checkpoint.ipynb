# %%
bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 
                30.7, 31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 
                33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 
                36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 
                450.0, 500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 
                700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 
                925.0, 975.0, 950.0]
smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 
                12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 
                13.4, 12.2, 19.7, 19.9]

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# data = [[l,w] for l,w in zip(bream_length + smelt_length,
#                       bream_weight + smelt_weight)]
data = np.column_stack((bream_length + smelt_length,
                      bream_weight + smelt_weight))
target = np.concatenate((np.ones(35), np.zeros(14)))


scaled_data = (data- data.mean(axis = 0))/data.std(axis = 0)

score = []
for i in range(5,50):
    knn = KNeighborsClassifier(n_neighbors= i)
    knn.fit(scaled_data, target)
    score.append(knn.score(scaled_data, target))

# %%
score = []
for i in range(5,50):
    knn = KNeighborsClassifier(n_neighbors= i)
    knn.fit(data, target)
    score.append(knn.score(data, target))

plt.figure(figsize=(12,6))
plt.xlabel('neighbors')
plt.ylabel('score')
plt.yticks(score, [round(s,4) for s in score])

plt.plot(range(5,50),score, 's-')
plt.show()

# %%
score_result = pd.DataFrame(np.column_stack((range(5,50), score)), columns = ['neighbors','score'])
score_result
# Out:
#     neighbors     score
# 0         5.0  1.000000
# 1         6.0  1.000000
# 2         7.0  1.000000
# 3         8.0  1.000000
# 4         9.0  1.000000
# 5        10.0  1.000000
# 6        11.0  1.000000
# 7        12.0  1.000000
# 8        13.0  1.000000
# 9        14.0  1.000000
# 10       15.0  1.000000
# 11       16.0  1.000000
# 12       17.0  1.000000
# 13       18.0  0.979592
# 14       19.0  0.979592
# 15       20.0  0.979592
# 16       21.0  0.979592
# 17       22.0  0.979592
# 18       23.0  0.979592
# 19       24.0  0.979592
# 20       25.0  0.979592
# 21       26.0  0.979592
# 22       27.0  0.979592
# 23       28.0  0.959184
# 24       29.0  0.714286
# 25       30.0  0.714286
# 26       31.0  0.714286
# 27       32.0  0.714286
# 28       33.0  0.714286
# 29       34.0  0.714286
# 30       35.0  0.714286
# 31       36.0  0.714286
# 32       37.0  0.714286
# 33       38.0  0.714286
# 34       39.0  0.714286
# 35       40.0  0.714286
# 36       41.0  0.714286
# ...

# %% [markdown]
# ### scaled

# %%
score = []
for i in range(5,50):
    knn = KNeighborsClassifier(n_neighbors= i)
    knn.fit(scaled_data, target)
    score.append(knn.score(scaled_data, target))

plt.figure(figsize=(12,6))
plt.xlabel('neighbors')
plt.ylabel('score')
plt.yticks(score, [round(s,4) for s in score])

plt.plot(range(5,50),score, 's-')
plt.show()

# %%
score_result = pd.DataFrame(np.column_stack((range(5,50), score)), columns = ['neighbors','score'])
score_result
# Out:
#     neighbors     score
# 0         5.0  1.000000
# 1         6.0  1.000000
# 2         7.0  1.000000
# 3         8.0  1.000000
# 4         9.0  1.000000
# 5        10.0  1.000000
# 6        11.0  1.000000
# 7        12.0  1.000000
# 8        13.0  1.000000
# 9        14.0  1.000000
# 10       15.0  1.000000
# 11       16.0  1.000000
# 12       17.0  1.000000
# 13       18.0  1.000000
# 14       19.0  1.000000
# 15       20.0  1.000000
# 16       21.0  1.000000
# 17       22.0  1.000000
# 18       23.0  1.000000
# 19       24.0  1.000000
# 20       25.0  1.000000
# 21       26.0  1.000000
# 22       27.0  1.000000
# 23       28.0  1.000000
# 24       29.0  0.714286
# 25       30.0  0.714286
# 26       31.0  0.714286
# 27       32.0  0.714286
# 28       33.0  0.714286
# 29       34.0  0.714286
# 30       35.0  0.714286
# 31       36.0  0.714286
# 32       37.0  0.714286
# 33       38.0  0.714286
# 34       39.0  0.714286
# 35       40.0  0.714286
# 36       41.0  0.714286
# ...
